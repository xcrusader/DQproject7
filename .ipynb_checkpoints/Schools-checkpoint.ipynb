# %% [markdown]
# # SAT Scores - A Plot is Afoot!

# %% [markdown]
# #### Can they reveal something more than scores?

# %% [markdown]
# # Index

# %% [markdown]
# - [1 Introduction](#1)
# - [2 Reading the Data](#2)
# - [3 Reading and Combining the Data](#3)
# - [4 And how are you related](#4)
# - [5 How safe is your burrow?](#5)
# - [6 The Race SAT race](#6)
# - [7 Men from Mars, Women from Venus](#7)
# - [8 Couple of Steps ahead..](#8)
# - [9 Conclusion](#9)
# - [10 Acknowledgement](#10)

# %% [markdown]
# # 1

# %% [markdown]
# ## Introduction

# %% [markdown]
# [SAT(Scholastic Aptitude Test)](#https://blog.prepscholar.com/what-is-the-sat-a-complete-explanation-of-the-test) is a test taken annualy by high school seniors in the US. The test helps colleges filter students for admissions and average SAT scores help identify school performance.
#
# The city of New York has published SAT scores by high school in additional to demographic data sets. Given the diverse mix of New York, SAT scores along with demographic data such as race, income and gender could reveal whether these scores are biased towards certains classes of the population with regards to performance.
#
# If analysis reveals that SAT scores are evenly distributed across all races it can be said that these scores are fair. However if a specific race or income bracket has a higher SAT score than another, it could be evidence that they are inequitable.

# %% [markdown]
# The goal of this project is to identify whether SAT scores along with demographic data can reveal more than the scores themselves. In order to identify these relations we will be looking at correlations between various data columns from different sources.
#
# Since data comes from multiple sources we could get some insights in to:
# - How much influence race has on SAT scores?
# - How the instituitions students study in affect SAT scores?
# - How gender affects SAT scores?
# - How locality plays a role in the outcome of SAT scores?
#
# This data should help answer many of these questions.

# %% [markdown]
# # 2

# %% [markdown]
# ## Reading The Data

# %% [markdown]
# The data sets provided include the following:
#
#    - [SAT scores by school](https://data.cityofnewyork.us/Education/SAT-Results/f9bf-2cp4)- SAT scores for each high school in New York City
#    - [School attendance](https://data.cityofnewyork.us/Education/School-Attendance-and-Enrollment-Statistics-by-Dis/7z8d-msnt) - Attendance information for each school in New York City
#    - [Class size](https://data.cityofnewyork.us/Education/2010-2011-Class-Size-School-level-detail/urz7-pzb3) - Information on class size for each school
#    - [AP test results ](https://data.cityofnewyork.us/Education/AP-College-Board-2010-School-Level-Results/itfs-ms3e) Advanced Placement (AP) exam results for each high school (passing an optional AP exam in a particular subject can earn a student college credit in that subject)
#    - [Graduation outcomes](https://data.cityofnewyork.us/Education/Graduation-Outcomes-Classes-Of-2005-2010-School-Le/vh2h-md7a) The percentage of students who graduated, and other outcome information
#    - [Demographics ](https://data.cityofnewyork.us/Education/School-Demographics-and-Accountability-Snapshot-20/ihfw-zy9j) Demographic information for each school
#    - School survey - Surveys of parents, teachers, and students at each school
#
# We shall read in the datasets below.

# %%
import pandas as pd
import numpy
import re
pd.options.display.max_columns = 50

data_files = ["ap_2010.csv",
              "class_size.csv",
              "demographics.csv",
              "graduation.csv",
              "hs_directory.csv",
              "sat_results.csv"]
data = {}

#Read datasets from the schools folder
for f in data_files:
    d = pd.read_csv("schools/{0}".format(f))
    data[f.replace(".csv", "")] = d

# %%
data["ap_2010"].head(3)
# Out:
#       DBN                    SchoolName AP Test Takers  Total Exams Taken  \
# 0  01M448  UNIVERSITY NEIGHBORHOOD H.S.              39                49
# 1  01M450        EAST SIDE COMMUNITY HS              19                21
# 2  01M515           LOWER EASTSIDE PREP              24                26
#
#   Number of Exams with scores 3 4 or 5
# 0                                   10
# 1                                    s
# 2                                   24

# %%
data["class_size"].head(2)
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# 0                           -                               19.0
# 1                           -                               21.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
#
#    SIZE OF LARGEST CLASS DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                   19.0         ATS                             NaN
# 1                   21.0         ATS                             NaN

# %%
data["demographics"].head(3)
# Out:
#       DBN                       Name  schoolyear fl_percent  frl_percent  \
# 0  01M015  P.S. 015 ROBERTO CLEMENTE    20052006       89.4          NaN
# 1  01M015  P.S. 015 ROBERTO CLEMENTE    20062007       89.4          NaN
# 2  01M015  P.S. 015 ROBERTO CLEMENTE    20072008       89.4          NaN
#
#    total_enrollment prek   k grade1 grade2 grade3 grade4 grade5 grade6 grade7  \
# 0               281   15  36     40     33     38     52     29     38    NaN
# 1               243   15  29     39     38     34     42     46    NaN    NaN
# 2               261   18  43     39     36     38     47     40    NaN    NaN
#
#   grade8 grade9 grade10 grade11 grade12  ell_num  ell_percent  sped_num  \
# 0    NaN    NaN     NaN     NaN     NaN     36.0         12.8      57.0
# 1    NaN    NaN     NaN     NaN     NaN     38.0         15.6      55.0
# 2    NaN    NaN     NaN     NaN     NaN     52.0         19.9      60.0
#
#    sped_percent ctt_num selfcontained_num  asian_num  asian_per  black_num  \
# 0          20.3      25                 9         10        3.6         74
# 1          22.6      19                15         18        7.4         68
# 2          23.0      20                14         16        6.1         77
#
#    black_per  hispanic_num  hispanic_per  white_num  white_per  male_num  \
# 0       26.3           189          67.3          5        1.8     158.0
# 1       28.0           153          63.0          4        1.6     140.0
# 2       29.5           157          60.2          7        2.7     143.0
#
#    male_per  female_num  female_per
# 0      56.2       123.0        43.8
# 1      57.6       103.0        42.4
# 2      54.8       118.0        45.2

# %%
data["graduation"].head(3)
# Out:
#     Demographic     DBN                            School Name Cohort  \
# 0  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2003
# 1  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2004
# 2  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2005
#
#    Total Cohort Total Grads - n Total Grads - % of cohort Total Regents - n  \
# 0             5               s                         s                 s
# 1            55              37                     67.3%                17
# 2            64              43                     67.2%                27
#
#   Total Regents - % of cohort Total Regents - % of grads Advanced Regents - n  \
# 0                           s                          s                    s
# 1                       30.9%                      45.9%                    0
# 2                       42.2%                      62.8%                    0
#
#   Advanced Regents - % of cohort Advanced Regents - % of grads  \
# 0                              s                             s
# 1                             0%                            0%
# 2                             0%                            0%
#
#   Regents w/o Advanced - n Regents w/o Advanced - % of cohort  \
# 0                        s                                  s
# 1                       17                              30.9%
# 2                       27                              42.2%
#
#   Regents w/o Advanced - % of grads Local - n Local - % of cohort  \
# 0                                 s         s                   s
# 1                             45.9%        20               36.4%
# 2                             62.8%        16                 25%
#
#     Local - % of grads Still Enrolled - n Still Enrolled - % of cohort  \
# 0                    s                  s                            s
# 1                54.1%                 15                        27.3%
# 2  37.200000000000003%                  9                        14.1%
#
#   Dropped Out - n Dropped Out - % of cohort
# 0               s                         s
# 1               3                      5.5%
# 2               9                     14.1%

# %%
data["hs_directory"].head(3)
# Out:
#       dbn                                  school_name      boro  \
# 0  17K548          Brooklyn School for Music & Theatre  Brooklyn
# 1  09X543             High School for Violin and Dance     Bronx
# 2  09X327  Comprehensive Model School Project M.S. 327     Bronx
#
#   building_code  phone_number    fax_number grade_span_min  grade_span_max  \
# 0          K440  718-230-6250  718-230-6262              9              12
# 1          X400  718-842-0687  718-589-9849              9              12
# 2          X240  718-294-8111  718-294-8109              6              12
#
#   expgrade_span_min  expgrade_span_max  \
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
#
#                                                  bus  \
# 0              B41, B43, B44-SBS, B45, B48, B49, B69
# 1  Bx13, Bx15, Bx17, Bx21, Bx35, Bx4, Bx41, Bx4A,...
# 2  Bx1, Bx11, Bx13, Bx18, Bx2, Bx3, Bx32, Bx35, Bx36
#
#                                               subway primary_address_line_1  \
# 0  2, 3, 4, 5, F, S to Botanic Garden ; B, Q to P...     883 Classon Avenue
# 1                              2, 5 to Intervale Ave       1110 Boston Road
# 2                4 to Mt Eden Ave ; B, D to 170th St     1501 Jerome Avenue
#
#        city state_code    zip                                       website  \
# 0  Brooklyn         NY  11225                           Bkmusicntheatre.com
# 1     Bronx         NY  10456                                  www.hsvd.org
# 2     Bronx         NY  10452  http://schools.nyc.gov/schoolportals/09/X327
#
#    total_students                          campus_name school_type  \
# 0           399.0  Prospect Heights Educational Campus         NaN
# 1           378.0            Morris Educational Campus         NaN
# 2           543.0  DOE New Settlement Community Campus         NaN
#
#                                   overview_paragraph  \
# 0  Brooklyn School for Music & Theatre (BSMT) use...
# 1  The High School for Violin and Dance (HSVD) is...
# 2  At the Comprehensive Model School Project (CMS...
#
#                                   program_highlights language_classes  \
# 0  We offer highly competitive positions in our D...          Spanish
# 1  Freshmen take both violin and dance; College N...          Spanish
# 2  After-school and Saturday Tutoring, Advisory, ...          Spanish
#
#                            advancedplacement_courses online_ap_courses  ...  \
# 0  English Language and Composition, United State...               NaN  ...
# 1                                                NaN               NaN  ...
# 2          Biology, Chemistry, United States History               NaN  ...
#
#                                     partner_highered  \
# 0                                                NaN
# 1  Hostos Community College, Monroe College, Teac...
# 2                                                NaN
#
#                                     partner_cultural  \
# 0  In 2002, Roundabout Theatre was selected by Ne...
# 1                                Bronx Arts Ensemble
# 2                                                NaN
#
#                                    partner_nonprofit    partner_corporate  \
# 0  One To World‘s Global Classroom connects New Y...                  NaN
# 1                                            buildOn  Print International
# 2                                                NaN                  NaN
#
#   partner_financial partner_other  \
# 0               NaN           NaN
# 1               NaN   Bronx Cares
# 2               NaN           NaN
#
#                                          addtl_info1  \
# 0                                                NaN
# 1  Our students are required to take four years o...
# 2  Dress Code Required: white or baby blue button...
#
#                                          addtl_info2 start_time end_time  \
# 0                                                NaN    8:10 AM  3:00 PM
# 1  Student Summer Orientation, Summer Internship ...    8:00 AM  3:00 PM
# 2                                                NaN    8:00 AM  4:00 PM
#
#                                          se_services ell_programs  \
# 0  This school will provide students with disabil...          ESL
# 1  This school will provide students with disabil...          ESL
# 2  This school will provide students with disabil...          ESL
#
#   school_accessibility_description number_programs  \
# 0          Functionally Accessible               1
# 1          Functionally Accessible               1
# 2          Functionally Accessible               1
#
#                                           priority01  \
# 0         Priority to Brooklyn students or residents
# 1  Priority to Bronx students or residents who at...
# 2                 Priority to continuing 8th graders
#
#                                           priority02  \
# 0                    Then to New York City residents
# 1  Then to New York City residents who attend an ...
# 2  Then to Bronx students or residents who attend...
#
#                                           priority03  \
# 0                                                NaN
# 1                Then to Bronx students or residents
# 2  Then to New York City residents who attend an ...
#
#                             priority04                       priority05  \
# 0                                  NaN                              NaN
# 1      Then to New York City residents                              NaN
# 2  Then to Bronx students or residents  Then to New York City residents
#
#   priority06 priority07  priority08 priority09 priority10  \
# 0        NaN        NaN         NaN        NaN        NaN
# 1        NaN        NaN         NaN        NaN        NaN
# 2        NaN        NaN         NaN        NaN        NaN
#
#                                           Location 1
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...
# 2  1501 Jerome Avenue\nBronx, NY 10452\n(40.84241...
#
# [3 rows x 58 columns]

# %%
data["sat_results"].head(3)
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370

# %% [markdown]
# The following issues have been realised after goind through the above datasets:
# - Column names are inconsistent throughtout the datasets. However considering that we will be eventually combining them, cleaning will be carried out on the combined data.
# - All the data sets have a DBN column, this should allow us to combine the sets more easily.
# - Some datasets like the *HS Directory* have a large number of columns which do not serve the purpose of analysis and will be removed.

# %% [markdown]
# Next we shall read data taken from the [surveys conducted](https://data.cityofnewyork.us/Education/NYC-School-Survey-2011/mnz3-dyi8) in the schools.
#
# The survey is conducted every year and its participants include parents, teachers and students associated to grades 6-12 of schools in New York. The above survey data is from 2011. The purpose of the survey is to give the participants an oppurtunity to present improvements and changes that they feel would help the school community.

# %%
#Read and combine survey data
all_survey = pd.read_csv("schools/survey_all.txt", delimiter="\t", encoding='windows-1252')
#d75_survey = pd.read_csv("schools/survey_d75.txt", delimiter="\t", encoding='windows-1252')

# %%
all_survey.head(2)
# Out:
#       dbn    bn                 schoolname  d75 studentssurveyed  highschool  \
# 0  01M015  M015  P.S. 015 Roberto Clemente    0               No         0.0
# 1  01M019  M019        P.S. 019 Asher Levy    0               No         0.0
#
#           schooltype  rr_s  rr_t  rr_p  N_s   N_t    N_p  nr_s  nr_t  nr_p  \
# 0  Elementary School   NaN    88    60  NaN  22.0   90.0     0    25   150
# 1  Elementary School   NaN   100    60  NaN  34.0  161.0     0    33   269
#
#    saf_p_11  com_p_11  eng_p_11  aca_p_11  saf_t_11  com_t_11  eng_t_11  \
# 0       8.5       7.6       7.5       7.8       7.5       7.8       7.6
# 1       8.4       7.6       7.6       7.8       8.6       8.5       8.9
#
#    aca_t_11  saf_s_11  ...  s_N_q14a_4  s_N_q14b_1  s_N_q14b_2  s_N_q14b_3  \
# 0       7.9       NaN  ...         NaN         NaN         NaN         NaN
# 1       9.1       NaN  ...         NaN         NaN         NaN         NaN
#
#    s_N_q14b_4  s_N_q14c_1  s_N_q14c_2  s_N_q14c_3  s_N_q14c_4  s_N_q14d_1  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14d_2  s_N_q14d_3  s_N_q14d_4  s_N_q14e_1  s_N_q14e_2  s_N_q14e_3  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14e_4  s_N_q14f_1  s_N_q14f_2  s_N_q14f_3  s_N_q14f_4  s_N_q14g_1  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14g_2  s_N_q14g_3  s_N_q14g_4
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
#
# [2 rows x 1942 columns]

# %%
#d75_survey.head(2)

# %% [markdown]
# Since the columns in both datasets are same they can be combined in to one data set to make the analysis easier.
#
# It must be noted that there are 1773 columns in each dataset. The data dictionary which is available in the link provided in an earlier cell reveals the following:
# - The first 7 columns are details specifically related to the school including such details as its location, its DBN etc.
# - The next 25 columns account for the number of participants (i.e parents, students and teachers) and the scores they assigned towards the level of safety, communication, student engagement and academic expecations.
# - The following 1729 colums are associated to scores assigned by participants to various questions asked in the survey.
# - The last 12 columns are not clear based on the description given in the data dictionary.

# %%
#survey = pd.concat([all_survey, d75_survey], axis=0)
survey=all_survey

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 3

# %% [markdown]
# ## Cleaning the Data

# %% [markdown]
# We can now individually clean each dataframe before combining them to one dataframe that would allow analysis. Something we noted earlier is that most of the dataframes had a common column called DBN.
#
# [DBN or District Borough Number](https://teachnyc.zendesk.com/hc/en-us/articles/360053601831-What-is-a-DBN-District-Borough-Number-) is a unique school ID alloted to each school in the various districts of the five boroughs of New York. To enable better analysis, data from the various sources will be consolidated to a single table wherein the the DBN will be the unique identifier. As we analyse each dataframe we must ensure that we can consolidate the data in it based on the DBN. This will help us combine the data to a single dataset.

# %% [markdown]
# #### Cleaning *ap_2010* dataframe

# %%
data['ap_2010']['DBN'].shape[0] == data['ap_2010']['DBN'].unique().shape[0]
# Out:
# False

# %%
data['ap_2010'][data['ap_2010']['DBN'] == '04M610']
# Out:
#        DBN                                         SchoolName AP Test Takers   \
# 51  04M610  THE YOUNG WOMEN'S LEADERSHIP SCHOOL OF EAST HA...              41
# 52  04M610                       YOUNG WOMEN'S LEADERSHIP SCH               s
#
#    Total Exams Taken Number of Exams with scores 3 4 or 5
# 51                55                                   29
# 52                 s                                    s

# %% [markdown]
# One school in the dataset has been repeated. The data associated to the duplicate school seems to be incorrect and will be removed. The column names also need to be standardized.

# %%
data['ap_2010']=data['ap_2010'].drop(52)

# %% [markdown]
# We have dropped the incorrect column. Next we shall verify whether the data types of all the columns are as expected.

# %%
data['ap_2010'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 257
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DBN                                   257 non-null    object
#  1   SchoolName                            257 non-null    object
#  2   AP Test Takers                        257 non-null    object
#  3   Total Exams Taken                     257 non-null    object
#  4   Number of Exams with scores 3 4 or 5  257 non-null    object
# dtypes: object(5)
# memory usage: 12.0+ KB

# %% [markdown]
# The data type of all the columns is string. However, the last 3 columns are expected to tbe numeric values. We will have to correct this by converting the columns to numeric.

# %%
cols = ['AP Test Takers ', 'Total Exams Taken', 'Number of Exams with scores 3 4 or 5']

for col in cols:
    data["ap_2010"][col] = pd.to_numeric(data["ap_2010"][col], errors="coerce")

# %% [markdown]
# Now that we have converted the columns to the numeric type, all thats left is to clean the name of the columns.

# %%
data['ap_2010'].rename(columns={'DBN':'dbn',"SchoolName":"school_name",
                                "AP Test Takers ":"ap_test_takers",
                                "Total Exams Taken":"total_exams_taken",
                                "Number of Exams with scores 3 4 or 5":"#_exams_with_high_scores"},inplace=True)
data['ap_2010'].columns
# Out:
# Index(['dbn', 'school_name', 'ap_test_takers', 'total_exams_taken',
#        '#_exams_with_high_scores'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *class_size* dataframe

# %%
data['class_size'].head(3)
# Out:
#    CSD BOROUGH SCHOOL CODE                SCHOOL NAME GRADE  PROGRAM TYPE  \
# 0    1       M        M015  P.S. 015 Roberto Clemente     0K       GEN ED
# 1    1       M        M015  P.S. 015 Roberto Clemente     0K          CTT
# 2    1       M        M015  P.S. 015 Roberto Clemente     01       GEN ED
#
#   CORE SUBJECT (MS CORE and 9-12 ONLY) CORE COURSE (MS CORE and 9-12 ONLY)  \
# 0                                    -                                   -
# 1                                    -                                   -
# 2                                    -                                   -
#
#   SERVICE CATEGORY(K-9* ONLY)  NUMBER OF STUDENTS / SEATS FILLED  \
# 0                           -                               19.0
# 1                           -                               21.0
# 2                           -                               17.0
#
#    NUMBER OF SECTIONS  AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  \
# 0                 1.0                19.0                    19.0
# 1                 1.0                21.0                    21.0
# 2                 1.0                17.0                    17.0
#
#    SIZE OF LARGEST CLASS DATA SOURCE  SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                   19.0         ATS                             NaN
# 1                   21.0         ATS                             NaN
# 2                   17.0         ATS                             NaN

# %%
data['class_size']['PROGRAM TYPE'].value_counts()
# Out:
# GEN ED     14545
# CTT         7460
# SPEC ED     3653
# G&T          469
# Name: PROGRAM TYPE, dtype: int64

# %% [markdown]
# After analysing the dataframe a couple of observations were made:
# - The dataframe does not contain a DBN column. One would have to be created with the associated data
# - The *GRADE* column classifies each school based on the grades they handle. A grade *02* means that the school handles only grade 2, a grade of 0K-09 means the school handles all grades till year 9. Our focus is on students who attend SAT exams. We will therefore need to filter schools that handle only grades 09-12
# - Each school has a specific program type. [*CTT and SPEC ED*](https://www.scholastic.com/parents/school-success/school-involvement/eip-ctt-odd-_-omg-decoding-special-education-acronyms0.html) program types are specially designed for students who have special needs. [G&T](https://www.schools.nyc.gov/enrollment/enroll-grade-by-grade/gifted-and-talented) is for students on the other end of the spectrum. Our focus is on schools of the *GEN ED* program type. Again we will need to filter schools on this basis.
# - The dataframe has multiple instances for each school because of the columns associated to subjects. For each subject taught in the school, the school record has been repeated. We will need to aggregate the data so that we have a single record for each school. This should also help to reduce the number of columns.
# - Finally the name of columns need to be standardized

# %% [markdown]
# The *DBN* data for each school can be created by combining data in the *CSD* column to the data in the *SCHOOL CODE* column.

# %%
def pad_csd(num):
    string_representation = str(num)
    if len(string_representation) > 1:
        return string_representation
    else:
        return "0" + string_representation
    
data["class_size"]["padded_csd"] = data["class_size"]["CSD"].apply(pad_csd)
data["class_size"]["DBN"] = data["class_size"]["padded_csd"] + data["class_size"]["SCHOOL CODE"]

# %%
class_size = data["class_size"]
class_size[(class_size["GRADE "] == "09-12") & (class_size["PROGRAM TYPE"] == "GEN ED")]
class_size = class_size.groupby("DBN").agg(numpy.mean).round(2)
class_size.reset_index(inplace=True)
class_size.head(3)
# Out:
#       DBN  CSD  NUMBER OF STUDENTS / SEATS FILLED  NUMBER OF SECTIONS  \
# 0  01M015    1                              17.73                1.09
# 1  01M019    1                              24.25                1.33
# 2  01M020    1                              43.92                2.08
#
#    AVERAGE CLASS SIZE  SIZE OF SMALLEST CLASS  SIZE OF LARGEST CLASS  \
# 0               16.55                   16.45                  16.64
# 1               17.62                   17.33                  17.92
# 2               21.98                   21.31                  22.54
#
#    SCHOOLWIDE PUPIL-TEACHER RATIO
# 0                             8.4
# 1                            10.0
# 2                            13.4

# %%
class_size.rename(columns={"NUMBER OF STUDENTS / SEATS FILLED":"avg_students_to_seats",
                           "NUMBER OF SECTIONS":"avg_sections_count",
                           "AVERAGE CLASS SIZE":"avg_class_size","SIZE OF SMALLEST CLASS":"avg_small_class_size",
                           "SIZE OF LARGEST CLASS":"avg_large_class_size",
                           "SCHOOLWIDE PUPIL-TEACHER RATIO":"avg_pupil_teacher_ratio"},inplace=True)
class_size.columns = class_size.columns.str.lower()
class_size.columns
# Out:
# Index(['dbn', 'csd', 'avg_students_to_seats', 'avg_sections_count',
#        'avg_class_size', 'avg_small_class_size', 'avg_large_class_size',
#        'avg_pupil_teacher_ratio'],
#       dtype='object')

# %%
class_size
# Out:
#          dbn  csd  avg_students_to_seats  avg_sections_count  avg_class_size  \
# 0     01M015    1                  17.73                1.09           16.55
# 1     01M019    1                  24.25                1.33           17.62
# 2     01M020    1                  43.92                2.08           21.98
# 3     01M034    1                  38.04                1.69           21.46
# 4     01M063    1                  16.40                1.00           16.40
# ...      ...  ...                    ...                 ...             ...
# 1482  32K549   32                  65.20                2.87           23.53
# 1483  32K552   32                  72.38                3.21           21.57
# 1484  32K554   32                  60.17                3.07           20.94
# 1485  32K556   32                  93.52                4.13           20.45
# 1486  32K564   32                 130.40                5.20           24.97
#
#       avg_small_class_size  avg_large_class_size  avg_pupil_teacher_ratio
# 0                    16.45                 16.64                      8.4
# 1                    17.33                 17.92                     10.0
# 2                    21.31                 22.54                     13.4
# 3                    20.73                 22.04                      9.6
# 4                    16.40                 16.40                      7.6
# ...                    ...                   ...                      ...
# 1482                 21.07                 26.17                     12.2
# 1483                 18.62                 24.66                     13.1
# 1484                 18.10                 24.07                     16.9
# 1485                 15.91                 23.83                     14.7
# 1486                 20.40                 28.33                     17.1
#
# [1487 rows x 8 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *demograpics* dataframe

# %%
data["demographics"].head(3)
# Out:
#       DBN                       Name  schoolyear fl_percent  frl_percent  \
# 0  01M015  P.S. 015 ROBERTO CLEMENTE    20052006       89.4          NaN
# 1  01M015  P.S. 015 ROBERTO CLEMENTE    20062007       89.4          NaN
# 2  01M015  P.S. 015 ROBERTO CLEMENTE    20072008       89.4          NaN
#
#    total_enrollment prek   k grade1 grade2 grade3 grade4 grade5 grade6 grade7  \
# 0               281   15  36     40     33     38     52     29     38    NaN
# 1               243   15  29     39     38     34     42     46    NaN    NaN
# 2               261   18  43     39     36     38     47     40    NaN    NaN
#
#   grade8 grade9 grade10 grade11 grade12  ell_num  ell_percent  sped_num  \
# 0    NaN    NaN     NaN     NaN     NaN     36.0         12.8      57.0
# 1    NaN    NaN     NaN     NaN     NaN     38.0         15.6      55.0
# 2    NaN    NaN     NaN     NaN     NaN     52.0         19.9      60.0
#
#    sped_percent ctt_num selfcontained_num  asian_num  asian_per  black_num  \
# 0          20.3      25                 9         10        3.6         74
# 1          22.6      19                15         18        7.4         68
# 2          23.0      20                14         16        6.1         77
#
#    black_per  hispanic_num  hispanic_per  white_num  white_per  male_num  \
# 0       26.3           189          67.3          5        1.8     158.0
# 1       28.0           153          63.0          4        1.6     140.0
# 2       29.5           157          60.2          7        2.7     143.0
#
#    male_per  female_num  female_per
# 0      56.2       123.0        43.8
# 1      57.6       103.0        42.4
# 2      54.8       118.0        45.2

# %% [markdown]
# The following observations were made after analysing the dataframe:
# - There are multiple *schoolyear*. Our focus will be only on the *schoolyear* *20112012* as it is the latest data in the dataset
# - There are a number of columns in this dataset that do not contribute to our analysis and must be removed. These include:
#     - fl/frl percent associated to free lunch programs
#     - all the grade columns
#     - all columns associated to special education
# - *Name* and *DBN* columns need to be standardized

# %%
#Filter demographic data for school year 2011-12
data["demographics"] = data["demographics"][data["demographics"]["schoolyear"] == 20112012]

# %%
cols = ["DBN","Name","schoolyear","total_enrollment",
        "asian_num","asian_per","black_num","black_per",
        "hispanic_num","hispanic_per","white_num","white_per",
        "male_num","male_per","female_num","female_per"]
data["demographics"] = data["demographics"][cols]
data["demographics"].columns = data["demographics"].columns.str.lower()
data["demographics"].columns
# Out:
# Index(['dbn', 'name', 'schoolyear', 'total_enrollment', 'asian_num',
#        'asian_per', 'black_num', 'black_per', 'hispanic_num', 'hispanic_per',
#        'white_num', 'white_per', 'male_num', 'male_per', 'female_num',
#        'female_per'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *graduation* column

# %%
data["graduation"].head(3)
# Out:
#     Demographic     DBN                            School Name Cohort  \
# 0  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2003
# 1  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2004
# 2  Total Cohort  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL   2005
#
#    Total Cohort Total Grads - n Total Grads - % of cohort Total Regents - n  \
# 0             5               s                         s                 s
# 1            55              37                     67.3%                17
# 2            64              43                     67.2%                27
#
#   Total Regents - % of cohort Total Regents - % of grads Advanced Regents - n  \
# 0                           s                          s                    s
# 1                       30.9%                      45.9%                    0
# 2                       42.2%                      62.8%                    0
#
#   Advanced Regents - % of cohort Advanced Regents - % of grads  \
# 0                              s                             s
# 1                             0%                            0%
# 2                             0%                            0%
#
#   Regents w/o Advanced - n Regents w/o Advanced - % of cohort  \
# 0                        s                                  s
# 1                       17                              30.9%
# 2                       27                              42.2%
#
#   Regents w/o Advanced - % of grads Local - n Local - % of cohort  \
# 0                                 s         s                   s
# 1                             45.9%        20               36.4%
# 2                             62.8%        16                 25%
#
#     Local - % of grads Still Enrolled - n Still Enrolled - % of cohort  \
# 0                    s                  s                            s
# 1                54.1%                 15                        27.3%
# 2  37.200000000000003%                  9                        14.1%
#
#   Dropped Out - n Dropped Out - % of cohort
# 0               s                         s
# 1               3                      5.5%
# 2               9                     14.1%

# %% [markdown]
# Observations made for the *graduation* dataframe include:
# - There are multiple *Demographics*. Cohorts are essentially groupings. Analysing demographics based on cohorts tend to be more accurate as they are analyzed for a time period. Since our analysis is not focused on a particular group, we will be considering *Total Cohort*. We will need to filter the data accordingly.
# - The *Cohort* column contains multiple years we shall consider the latest yeat which is 2006. Again we need to filter the dataset to reflect the same.
# - There are multiple column where in the value for the columns is 's'. This is likely to be incomplete or unknown data and 's' could be a filler. All records containing this kind of data will be removed.
# - Most of the numerical columns are strings and contains the '%' charachter which must be removed
# - The names of the columns in the dataset need to be standardized.

# %%
#Filter graduation data for the Demographic Total Cohort and the cohort 2006
data["graduation"] = data["graduation"][(data["graduation"]["Cohort"] == "2006") & (data["graduation"]["Demographic"] == "Total Cohort")]

#Remove rows where Total Grad - n=='s'
data["graduation"] = data['graduation'][data['graduation']['Total Grads - n']!='s']

# %%
data["graduation"][data['graduation']['Total Grads - n']=='0']
# Out:
#        Demographic     DBN                           School Name Cohort  \
# 1674  Total Cohort  17K533  SCHOOL FOR DEMOCRACY AND  LEADERSHIP   2006
#
#       Total Cohort Total Grads - n Total Grads - % of cohort  \
# 1674            74               0                        0%
#
#      Total Regents - n Total Regents - % of cohort Total Regents - % of grads  \
# 1674                 0                          0%                          .
#
#      Advanced Regents - n Advanced Regents - % of cohort  \
# 1674                    0                             0%
#
#      Advanced Regents - % of grads Regents w/o Advanced - n  \
# 1674                             .                        0
#
#      Regents w/o Advanced - % of cohort Regents w/o Advanced - % of grads  \
# 1674                                 0%                                 .
#
#      Local - n Local - % of cohort Local - % of grads Still Enrolled - n  \
# 1674         0                  0%                  .                 63
#
#      Still Enrolled - % of cohort Dropped Out - n Dropped Out - % of cohort
# 1674                        85.1%               6                      8.1%

# %%
#Remove row where Total Grad - n==0 because some columns have the value '.'
data["graduation"] = data["graduation"][data['graduation']['Total Grads - n']!='0']

# %%
#Select a subset of the graduation column
grad_subset=data['graduation'].loc[:,'Total Grads - n':'Dropped Out - % of cohort']

#Change the type in the subset columns to float. Remove '%' from the columns
grad_subset=grad_subset.applymap(lambda x: round(float(str(x).replace('%','')),2))

#Re-assign the cleaned values
data['graduation'].loc[:,'Total Grads - n':'Dropped Out - % of cohort']=grad_subset
data['graduation'].loc[:,'Total Grads - n':'Dropped Out - % of cohort']
# Out:
#       Total Grads - n  Total Grads - % of cohort  Total Regents - n  \
# 3                43.0                       55.1               36.0
# 10               53.0                       42.7               42.0
# 17               70.0                       77.8               67.0
# 24               47.0                       56.0               40.0
# 31              105.0                       54.4               91.0
# ...               ...                        ...                ...
# 2467             74.0                       76.3               59.0
# 2474             55.0                       47.8               41.0
# 2480             36.0                       83.7               23.0
# 2487             65.0                       55.6               28.0
# 2494             10.0                        7.8                3.0
#
#       Total Regents - % of cohort  Total Regents - % of grads  \
# 3                            46.2                        83.7
# 10                           33.9                        79.2
# 17                           74.4                        95.7
# 24                           47.6                        85.1
# 31                           47.2                        86.7
# ...                           ...                         ...
# 2467                         60.8                        79.7
# 2474                         35.7                        74.5
# 2480                         53.5                        63.9
# 2487                         23.9                        43.1
# 2494                          2.3                        30.0
#
#       Advanced Regents - n  Advanced Regents - % of cohort  \
# 3                      0.0                             0.0
# 10                     8.0                             6.5
# 17                     0.0                             0.0
# 24                    17.0                            20.2
# 31                    69.0                            35.8
# ...                    ...                             ...
# 2467                   5.0                             5.2
# 2474                   1.0                             0.9
# 2480                   5.0                            11.6
# 2487                   5.0                             4.3
# 2494                   0.0                             0.0
#
#       Advanced Regents - % of grads  Regents w/o Advanced - n  \
# 3                               0.0                      36.0
# 10                             15.1                      34.0
# 17                              0.0                      67.0
# 24                             36.2                      23.0
# 31                             65.7                      22.0
# ...                             ...                       ...
# 2467                            6.8                      54.0
# 2474                            1.8                      40.0
# 2480                           13.9                      18.0
# 2487                            7.7                      23.0
# 2494                            0.0                       3.0
#
#       Regents w/o Advanced - % of cohort  Regents w/o Advanced - % of grads  \
# 3                                   46.2                               83.7
# 10                                  27.4                               64.2
# 17                                  74.4                               95.7
# 24                                  27.4                               48.9
# 31                                  11.4                               21.0
# ...                                  ...                                ...
# 2467                                55.7                               73.0
# 2474                                34.8                               72.7
# 2480                                41.9                               50.0
# 2487                                19.7                               35.4
# 2494                                 2.3                               30.0
#
#       Local - n  Local - % of cohort  Local - % of grads  Still Enrolled - n  \
# 3           7.0                  9.0                16.3                16.0
# 10         11.0                  8.9                20.8                46.0
# 17          3.0                  3.3                 4.3                15.0
# 24          7.0                  8.3                14.9                25.0
# 31         14.0                  7.3                13.3                53.0
# ...         ...                  ...                 ...                 ...
# 2467       15.0                 15.5                20.3                12.0
# 2474       14.0                 12.2                25.5                44.0
# 2480       13.0                 30.2                36.1                 5.0
# 2487       37.0                 31.6                56.9                24.0
# 2494        7.0                  5.5                70.0                63.0
#
#       Still Enrolled - % of cohort  Dropped Out - n  Dropped Out - % of cohort
# 3                             20.5             11.0                       14.1
# 10                            37.1             20.0                       16.1
# 17                            16.7              5.0                        5.6
# 24                            29.8              5.0                        6.0
# 31                            27.5             35.0                       18.1
# ...                            ...              ...                        ...
# 2467                          12.4              9.0                        9.3
# 2474                          38.3             10.0                        8.7
# 2480                          11.6              2.0                        4.7
# 2487                          20.5             22.0                       18.8
# 2494                          49.2             52.0                       40.6
#
# [377 rows x 18 columns]

# %%
#Clean the graduation column names
data["graduation"].columns = data["graduation"].columns.str.replace(' - ','_')
data["graduation"].columns = data["graduation"].columns.str.replace(" of ","_")
data["graduation"].columns = data["graduation"].columns.str.replace(" ","_")
data["graduation"].columns = data["graduation"].columns.str.lower()
data["graduation"].columns
# Out:
# Index(['demographic', 'dbn', 'school_name', 'cohort', 'total_cohort',
#        'total_grads_n', 'total_grads_%_cohort', 'total_regents_n',
#        'total_regents_%_cohort', 'total_regents_%_grads', 'advanced_regents_n',
#        'advanced_regents_%_cohort', 'advanced_regents_%_grads',
#        'regents_w/o_advanced_n', 'regents_w/o_advanced_%_cohort',
#        'regents_w/o_advanced_%_grads', 'local_n', 'local_%_cohort',
#        'local_%_grads', 'still_enrolled_n', 'still_enrolled_%_cohort',
#        'dropped_out_n', 'dropped_out_%_cohort'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *hs_directory*  dataframe

# %%
data["hs_directory"].head(2)
# Out:
#       dbn                          school_name      boro building_code  \
# 0  17K548  Brooklyn School for Music & Theatre  Brooklyn          K440
# 1  09X543     High School for Violin and Dance     Bronx          X400
#
#    phone_number    fax_number grade_span_min  grade_span_max  \
# 0  718-230-6250  718-230-6262              9              12
# 1  718-842-0687  718-589-9849              9              12
#
#   expgrade_span_min  expgrade_span_max  \
# 0               NaN                NaN
# 1               NaN                NaN
#
#                                                  bus  \
# 0              B41, B43, B44-SBS, B45, B48, B49, B69
# 1  Bx13, Bx15, Bx17, Bx21, Bx35, Bx4, Bx41, Bx4A,...
#
#                                               subway primary_address_line_1  \
# 0  2, 3, 4, 5, F, S to Botanic Garden ; B, Q to P...     883 Classon Avenue
# 1                              2, 5 to Intervale Ave       1110 Boston Road
#
#        city state_code    zip              website  total_students  \
# 0  Brooklyn         NY  11225  Bkmusicntheatre.com           399.0
# 1     Bronx         NY  10456         www.hsvd.org           378.0
#
#                            campus_name school_type  \
# 0  Prospect Heights Educational Campus         NaN
# 1            Morris Educational Campus         NaN
#
#                                   overview_paragraph  \
# 0  Brooklyn School for Music & Theatre (BSMT) use...
# 1  The High School for Violin and Dance (HSVD) is...
#
#                                   program_highlights language_classes  \
# 0  We offer highly competitive positions in our D...          Spanish
# 1  Freshmen take both violin and dance; College N...          Spanish
#
#                            advancedplacement_courses online_ap_courses  ...  \
# 0  English Language and Composition, United State...               NaN  ...
# 1                                                NaN               NaN  ...
#
#                                     partner_highered  \
# 0                                                NaN
# 1  Hostos Community College, Monroe College, Teac...
#
#                                     partner_cultural  \
# 0  In 2002, Roundabout Theatre was selected by Ne...
# 1                                Bronx Arts Ensemble
#
#                                    partner_nonprofit    partner_corporate  \
# 0  One To World‘s Global Classroom connects New Y...                  NaN
# 1                                            buildOn  Print International
#
#   partner_financial partner_other  \
# 0               NaN           NaN
# 1               NaN   Bronx Cares
#
#                                          addtl_info1  \
# 0                                                NaN
# 1  Our students are required to take four years o...
#
#                                          addtl_info2 start_time end_time  \
# 0                                                NaN    8:10 AM  3:00 PM
# 1  Student Summer Orientation, Summer Internship ...    8:00 AM  3:00 PM
#
#                                          se_services ell_programs  \
# 0  This school will provide students with disabil...          ESL
# 1  This school will provide students with disabil...          ESL
#
#   school_accessibility_description number_programs  \
# 0          Functionally Accessible               1
# 1          Functionally Accessible               1
#
#                                           priority01  \
# 0         Priority to Brooklyn students or residents
# 1  Priority to Bronx students or residents who at...
#
#                                           priority02  \
# 0                    Then to New York City residents
# 1  Then to New York City residents who attend an ...
#
#                             priority03                       priority04  \
# 0                                  NaN                              NaN
# 1  Then to Bronx students or residents  Then to New York City residents
#
#   priority05 priority06 priority07  priority08 priority09 priority10  \
# 0        NaN        NaN        NaN         NaN        NaN        NaN
# 1        NaN        NaN        NaN         NaN        NaN        NaN
#
#                                           Location 1
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...
#
# [2 rows x 58 columns]

# %%
data["hs_directory"].columns
# Out:
# Index(['dbn', 'school_name', 'boro', 'building_code', 'phone_number',
#        'fax_number', 'grade_span_min', 'grade_span_max', 'expgrade_span_min',
#        'expgrade_span_max', 'bus', 'subway', 'primary_address_line_1', 'city',
#        'state_code', 'zip', 'website', 'total_students', 'campus_name',
#        'school_type', 'overview_paragraph', 'program_highlights',
#        'language_classes', 'advancedplacement_courses', 'online_ap_courses',
#        'online_language_courses', 'extracurricular_activities',
#        'psal_sports_boys', 'psal_sports_girls', 'psal_sports_coed',
#        'school_sports', 'partner_cbo', 'partner_hospital', 'partner_highered',
#        'partner_cultural', 'partner_nonprofit', 'partner_corporate',
#        'partner_financial', 'partner_other', 'addtl_info1', 'addtl_info2',
#        'start_time', 'end_time', 'se_services', 'ell_programs',
#        'school_accessibility_description', 'number_programs', 'priority01',
#        'priority02', 'priority03', 'priority04', 'priority05', 'priority06',
#        'priority07', 'priority08', 'priority09', 'priority10', 'Location 1'],
#       dtype='object')

# %% [markdown]
# Analysis of the dataframe has revealed the following:
# - There are a number of columns in the dataframe that are irrelevant to our analysis that can be removed because most details pertain to the school itself like contact details etc. and are not useful for SAT related analysis.
# - The *Location 1* column could be parsed to extract latitudes and longitude related data for each school.

# %%
cols = ['dbn','zip','total_students','Location 1']
data["hs_directory"] = data["hs_directory"][cols]
data["hs_directory"].head(3)
# Out:
#       dbn    zip  total_students  \
# 0  17K548  11225           399.0
# 1  09X543  10456           378.0
# 2  09X327  10452           543.0
#
#                                           Location 1
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...
# 2  1501 Jerome Avenue\nBronx, NY 10452\n(40.84241...

# %%
# Parse location of each school by latitude and longitude
def find_lat(loc):
    coords = re.findall("\(.+, .+\)", loc)
    lat = coords[0].split(",")[0].replace("(", "")
    return lat

def find_lon(loc):
    coords = re.findall("\(.+, .+\)", loc)
    lon = coords[0].split(",")[1].replace(")", "").strip()
    return lon

data["hs_directory"]["lat"] = data["hs_directory"]["Location 1"].apply(find_lat)
data["hs_directory"]["lon"] = data["hs_directory"]["Location 1"].apply(find_lon)

data["hs_directory"]["lat"] = pd.to_numeric(data["hs_directory"]["lat"], errors="coerce")
data["hs_directory"]["lon"] = pd.to_numeric(data["hs_directory"]["lon"], errors="coerce")

data["hs_directory"].head()
# Out:
#       dbn    zip  total_students  \
# 0  17K548  11225           399.0
# 1  09X543  10456           378.0
# 2  09X327  10452           543.0
# 3  02M280  10038             NaN
# 4  28Q680  11432           811.0
#
#                                           Location 1        lat        lon
# 0  883 Classon Avenue\nBrooklyn, NY 11225\n(40.67...  40.670299 -73.961648
# 1  1110 Boston Road\nBronx, NY 10456\n(40.8276026...  40.827603 -73.904475
# 2  1501 Jerome Avenue\nBronx, NY 10452\n(40.84241...  40.842414 -73.916162
# 3  411 Pearl Street\nNew York, NY 10038\n(40.7106...  40.710679 -74.000807
# 4  160-20 Goethals Avenue\nJamaica, NY 11432\n(40...  40.718810 -73.806500

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *sat_results* dataframe

# %%
data['sat_results'].head(5)
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score
# 0                    363
# 1                    366
# 2                    370
# 3                    359
# 4                    384

# %%
data['sat_results'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DBN                              478 non-null    object
#  1   SCHOOL NAME                      478 non-null    object
#  2   Num of SAT Test Takers           478 non-null    object
#  3   SAT Critical Reading Avg. Score  478 non-null    object
#  4   SAT Math Avg. Score              478 non-null    object
#  5   SAT Writing Avg. Score           478 non-null    object
# dtypes: object(6)
# memory usage: 22.5+ KB

# %% [markdown]
# Observations after analysing the dataframe:
# - The score and count related columns are of type string. These need to be made numeric.
# - Column names need to be standardized.
# - A total score column could be introduced which is the sum of the average reading, average math and average writing score.

# %%
cols = ['SAT Math Avg. Score', 'SAT Critical Reading Avg. Score', 'SAT Writing Avg. Score']
for c in cols:
    data["sat_results"][c] = pd.to_numeric(data["sat_results"][c], errors="coerce")

# %%
#Rename sat_result columns
data['sat_results'].rename(columns={'DBN':'dbn',
                                    'Num of SAT Test Takers':'test_takers_count',
                                    'SAT Critical Reading Avg. Score':'avg_reading_score',
                                    'SAT Math Avg. Score':'avg_math_score',
                                    'SAT Writing Avg. Score':'avg_writing_score'},inplace=True)
data['sat_results']['avg_total_score'] = data['sat_results'][data['sat_results'].columns[3:6]].sum(axis=1)
data['sat_results'] = data['sat_results'][['dbn','test_takers_count','avg_reading_score',
                                           'avg_math_score','avg_writing_score','avg_total_score']]
data['sat_results'].head(3)
# Out:
#       dbn test_takers_count  avg_reading_score  avg_math_score  \
# 0  01M292                29              355.0           404.0
# 1  01M448                91              383.0           423.0
# 2  01M450                70              377.0           402.0
#
#    avg_writing_score  avg_total_score
# 0              363.0           1122.0
# 1              366.0           1172.0
# 2              370.0           1149.0

# %% [markdown]
# ---

# %% [markdown]
# #### Cleaning the *survey* dataframe

# %%
survey.head(3)
# Out:
#       dbn    bn                 schoolname  d75 studentssurveyed  highschool  \
# 0  01M015  M015  P.S. 015 Roberto Clemente    0               No         0.0
# 1  01M019  M019        P.S. 019 Asher Levy    0               No         0.0
# 2  01M020  M020       P.S. 020 Anna Silver    0               No         0.0
#
#           schooltype  rr_s  rr_t  rr_p  N_s   N_t    N_p  nr_s  nr_t  nr_p  \
# 0  Elementary School   NaN    88    60  NaN  22.0   90.0     0    25   150
# 1  Elementary School   NaN   100    60  NaN  34.0  161.0     0    33   269
# 2  Elementary School   NaN    88    73  NaN  42.0  367.0     0    48   505
#
#    saf_p_11  com_p_11  eng_p_11  aca_p_11  saf_t_11  com_t_11  eng_t_11  \
# 0       8.5       7.6       7.5       7.8       7.5       7.8       7.6
# 1       8.4       7.6       7.6       7.8       8.6       8.5       8.9
# 2       8.9       8.3       8.3       8.6       7.6       6.3       6.8
#
#    aca_t_11  saf_s_11  ...  s_N_q14a_4  s_N_q14b_1  s_N_q14b_2  s_N_q14b_3  \
# 0       7.9       NaN  ...         NaN         NaN         NaN         NaN
# 1       9.1       NaN  ...         NaN         NaN         NaN         NaN
# 2       7.5       NaN  ...         NaN         NaN         NaN         NaN
#
#    s_N_q14b_4  s_N_q14c_1  s_N_q14c_2  s_N_q14c_3  s_N_q14c_4  s_N_q14d_1  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14d_2  s_N_q14d_3  s_N_q14d_4  s_N_q14e_1  s_N_q14e_2  s_N_q14e_3  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14e_4  s_N_q14f_1  s_N_q14f_2  s_N_q14f_3  s_N_q14f_4  s_N_q14g_1  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
#
#    s_N_q14g_2  s_N_q14g_3  s_N_q14g_4
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
#
# [3 rows x 1942 columns]

# %% [markdown]
# Of the above mentioned columns we shall consider a subset because of the following reasons:
# - The 5 columns after DBN are not required or not relevant to our analysis as the data associated to them would already be in the previously processed data sets
# - Since we do not have clarity on the questions that were asked or what the last twelve columns are for we shall avoid the last 1741 columns and consider just the first 32 columns.
#
# This means besides the *dbn* column we would only have to consider the 25 columns after the *studentsurvey* column associated to the scores linked to safety, communication, engagement and academic expectation.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
subset = survey['dbn']
survey_subset = survey[survey.columns[7:32]].copy()
survey_subset['dbn'] = survey['dbn']
survey_subset.columns
# Out:
# Index(['rr_s', 'rr_t', 'rr_p', 'N_s', 'N_t', 'N_p', 'nr_s', 'nr_t', 'nr_p',
#        'saf_p_11', 'com_p_11', 'eng_p_11', 'aca_p_11', 'saf_t_11', 'com_t_11',
#        'eng_t_11', 'aca_t_11', 'saf_s_11', 'com_s_11', 'eng_s_11', 'aca_s_11',
#        'saf_tot_11', 'com_tot_11', 'eng_tot_11', 'aca_tot_11', 'dbn'],
#       dtype='object')

# %% [markdown]
# ---

# %% [markdown]
# ####  Combining the cleaned data

# %% [markdown]
# Now that we have cleared the data to level that allows easier analysis, we can combine the dataframes in to a single dataframe. We shall do the same below

# %%
combined = data["sat_results"]

combined = combined.merge(data["ap_2010"], on="dbn", how="left")
combined = combined.merge(data["graduation"], on="dbn", how="left")
combined.tail(10)
# Out:
#         dbn test_takers_count  avg_reading_score  avg_math_score  \
# 468  75K371                 s                NaN             NaN
# 469  75M035                 s                NaN             NaN
# 470  75Q256                 s                NaN             NaN
# 471  75Q811                32              429.0           444.0
# 472  75R025                 s                NaN             NaN
# 473  75X012                 s                NaN             NaN
# 474  75X754                 s                NaN             NaN
# 475  79M645                 s                NaN             NaN
# 476  79Q950                 8              496.0           400.0
# 477  79X490                 9              367.0           370.0
#
#      avg_writing_score  avg_total_score school_name_x  ap_test_takers  \
# 468                NaN              0.0           NaN             NaN
# 469                NaN              0.0           NaN             NaN
# 470                NaN              0.0           NaN             NaN
# 471              433.0           1306.0           NaN             NaN
# 472                NaN              0.0           NaN             NaN
# 473                NaN              0.0           NaN             NaN
# 474                NaN              0.0           NaN             NaN
# 475                NaN              0.0           NaN             NaN
# 476              426.0           1322.0           NaN             NaN
# 477              360.0           1097.0           NaN             NaN
#
#      total_exams_taken  #_exams_with_high_scores demographic school_name_y  \
# 468                NaN                       NaN         NaN           NaN
# 469                NaN                       NaN         NaN           NaN
# 470                NaN                       NaN         NaN           NaN
# 471                NaN                       NaN         NaN           NaN
# 472                NaN                       NaN         NaN           NaN
# 473                NaN                       NaN         NaN           NaN
# 474                NaN                       NaN         NaN           NaN
# 475                NaN                       NaN         NaN           NaN
# 476                NaN                       NaN         NaN           NaN
# 477                NaN                       NaN         NaN           NaN
#
#     cohort  total_cohort  total_grads_n  total_grads_%_cohort  \
# 468    NaN           NaN            NaN                   NaN
# 469    NaN           NaN            NaN                   NaN
# 470    NaN           NaN            NaN                   NaN
# 471    NaN           NaN            NaN                   NaN
# 472    NaN           NaN            NaN                   NaN
# 473    NaN           NaN            NaN                   NaN
# 474    NaN           NaN            NaN                   NaN
# 475    NaN           NaN            NaN                   NaN
# 476    NaN           NaN            NaN                   NaN
# 477    NaN           NaN            NaN                   NaN
#
#      total_regents_n  total_regents_%_cohort  total_regents_%_grads  \
# 468              NaN                     NaN                    NaN
# 469              NaN                     NaN                    NaN
# 470              NaN                     NaN                    NaN
# 471              NaN                     NaN                    NaN
# 472              NaN                     NaN                    NaN
# 473              NaN                     NaN                    NaN
# 474              NaN                     NaN                    NaN
# 475              NaN                     NaN                    NaN
# 476              NaN                     NaN                    NaN
# 477              NaN                     NaN                    NaN
#
#      advanced_regents_n  advanced_regents_%_cohort  advanced_regents_%_grads  \
# 468                 NaN                        NaN                       NaN
# 469                 NaN                        NaN                       NaN
# 470                 NaN                        NaN                       NaN
# 471                 NaN                        NaN                       NaN
# 472                 NaN                        NaN                       NaN
# 473                 NaN                        NaN                       NaN
# 474                 NaN                        NaN                       NaN
# 475                 NaN                        NaN                       NaN
# 476                 NaN                        NaN                       NaN
# 477                 NaN                        NaN                       NaN
#
#      regents_w/o_advanced_n  regents_w/o_advanced_%_cohort  \
# 468                     NaN                            NaN
# 469                     NaN                            NaN
# 470                     NaN                            NaN
# 471                     NaN                            NaN
# 472                     NaN                            NaN
# 473                     NaN                            NaN
# 474                     NaN                            NaN
# 475                     NaN                            NaN
# 476                     NaN                            NaN
# 477                     NaN                            NaN
#
#      regents_w/o_advanced_%_grads  local_n  local_%_cohort  local_%_grads  \
# 468                           NaN      NaN             NaN            NaN
# 469                           NaN      NaN             NaN            NaN
# 470                           NaN      NaN             NaN            NaN
# 471                           NaN      NaN             NaN            NaN
# 472                           NaN      NaN             NaN            NaN
# 473                           NaN      NaN             NaN            NaN
# 474                           NaN      NaN             NaN            NaN
# 475                           NaN      NaN             NaN            NaN
# 476                           NaN      NaN             NaN            NaN
# 477                           NaN      NaN             NaN            NaN
#
#      still_enrolled_n  still_enrolled_%_cohort  dropped_out_n  \
# 468               NaN                      NaN            NaN
# 469               NaN                      NaN            NaN
# 470               NaN                      NaN            NaN
# 471               NaN                      NaN            NaN
# 472               NaN                      NaN            NaN
# 473               NaN                      NaN            NaN
# 474               NaN                      NaN            NaN
# 475               NaN                      NaN            NaN
# 476               NaN                      NaN            NaN
# 477               NaN                      NaN            NaN
#
#      dropped_out_%_cohort
# 468                   NaN
# 469                   NaN
# 470                   NaN
# 471                   NaN
# 472                   NaN
# 473                   NaN
# 474                   NaN
# 475                   NaN
# 476                   NaN
# 477                   NaN

# %% [markdown]
# After combining two datasets what immediately comes to notice is that many of the schools towards the end are schools associated to special education and alternative education. These school districts are preceded by the numbers 75 and 79 respectively. All DoE(Department of Education) school districts are highlighted in this [map](https://video.eschoolsolutions.com/udocs/DistrictMap.pdf). The special education and alternative education are spread across these districts. These special district codes help to identify them.
#
# We shall be dropping these schools from our analysis, if they exist in our records after combining the other  as we are more focused on the *General Education* category.

# %%
combined = combined.merge(class_size, how = "inner")
combined = combined.merge(data["demographics"], how = "inner")
combined = combined.merge(survey_subset, how = "inner")
combined = combined.merge(data["hs_directory"], how = "inner")
combined.columns
# Out:
# Index(['dbn', 'test_takers_count', 'avg_reading_score', 'avg_math_score',
#        'avg_writing_score', 'avg_total_score', 'school_name_x',
#        'ap_test_takers', 'total_exams_taken', '#_exams_with_high_scores',
#        'demographic', 'school_name_y', 'cohort', 'total_cohort',
#        'total_grads_n', 'total_grads_%_cohort', 'total_regents_n',
#        'total_regents_%_cohort', 'total_regents_%_grads', 'advanced_regents_n',
#        'advanced_regents_%_cohort', 'advanced_regents_%_grads',
#        'regents_w/o_advanced_n', 'regents_w/o_advanced_%_cohort',
#        'regents_w/o_advanced_%_grads', 'local_n', 'local_%_cohort',
#        'local_%_grads', 'still_enrolled_n', 'still_enrolled_%_cohort',
#        'dropped_out_n', 'dropped_out_%_cohort', 'csd', 'avg_students_to_seats',
#        'avg_sections_count', 'avg_class_size', 'avg_small_class_size',
#        'avg_large_class_size', 'avg_pupil_teacher_ratio', 'name', 'schoolyear',
#        'total_enrollment', 'asian_num', 'asian_per', 'black_num', 'black_per',
#        'hispanic_num', 'hispanic_per', 'white_num', 'white_per', 'male_num',
#        'male_per', 'female_num', 'female_per', 'rr_s', 'rr_t', 'rr_p', 'N_s',
#        'N_t', 'N_p', 'nr_s', 'nr_t', 'nr_p', 'saf_p_11', 'com_p_11',
#        'eng_p_11', 'aca_p_11', 'saf_t_11', 'com_t_11', 'eng_t_11', 'aca_t_11',
#        'saf_s_11', 'com_s_11', 'eng_s_11', 'aca_s_11', 'saf_tot_11',
#        'com_tot_11', 'eng_tot_11', 'aca_tot_11', 'zip', 'total_students',
#        'Location 1', 'lat', 'lon'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
nullmap=combined.isnull()

fig = plt.subplots(figsize=(10,7))
sns.heatmap(nullmap,cbar=False)
plt.show()

# %%
combined.shape
# Out:
# (365, 84)

# %% [markdown]
# After having combined our dataset we can see that there are a few schools that are missing SAT related data. Since the SAT related data for each school is critical to our analysis it would be unwise to fill these values with the average SAT scores of all school. Therefore we shall remove these schools.
#
# Most of the null data observed is from the *graduation* dataframe. We shall deal with this separately, if required during analysis.
#
# We shall also be removing the *school_x* column as it is a duplicate of the column *school_y* and it has a lot of missing data.

# %%
combined = combined[combined['avg_writing_score'].notnull()]
nullmap=combined.isnull()

fig = plt.subplots(figsize=(10,7))
sns.heatmap(nullmap,cbar=False)
plt.show()

# %%
combined.shape
# Out:
# (336, 84)

# %%
combined.drop(columns="school_name_x",inplace=True)
combined.rename(columns={"school_name_y":"school_name"},inplace=True)
combined["school_name"]=combined["school_name"].str.title()
combined = combined.reset_index()
combined.columns
# Out:
# Index(['index', 'dbn', 'test_takers_count', 'avg_reading_score',
#        'avg_math_score', 'avg_writing_score', 'avg_total_score',
#        'ap_test_takers', 'total_exams_taken', '#_exams_with_high_scores',
#        'demographic', 'school_name', 'cohort', 'total_cohort', 'total_grads_n',
#        'total_grads_%_cohort', 'total_regents_n', 'total_regents_%_cohort',
#        'total_regents_%_grads', 'advanced_regents_n',
#        'advanced_regents_%_cohort', 'advanced_regents_%_grads',
#        'regents_w/o_advanced_n', 'regents_w/o_advanced_%_cohort',
#        'regents_w/o_advanced_%_grads', 'local_n', 'local_%_cohort',
#        'local_%_grads', 'still_enrolled_n', 'still_enrolled_%_cohort',
#        'dropped_out_n', 'dropped_out_%_cohort', 'csd', 'avg_students_to_seats',
#        'avg_sections_count', 'avg_class_size', 'avg_small_class_size',
#        'avg_large_class_size', 'avg_pupil_teacher_ratio', 'name', 'schoolyear',
#        'total_enrollment', 'asian_num', 'asian_per', 'black_num', 'black_per',
#        'hispanic_num', 'hispanic_per', 'white_num', 'white_per', 'male_num',
#        'male_per', 'female_num', 'female_per', 'rr_s', 'rr_t', 'rr_p', 'N_s',
#        'N_t', 'N_p', 'nr_s', 'nr_t', 'nr_p', 'saf_p_11', 'com_p_11',
#        'eng_p_11', 'aca_p_11', 'saf_t_11', 'com_t_11', 'eng_t_11', 'aca_t_11',
#        'saf_s_11', 'com_s_11', 'eng_s_11', 'aca_s_11', 'saf_tot_11',
#        'com_tot_11', 'eng_tot_11', 'aca_tot_11', 'zip', 'total_students',
#        'Location 1', 'lat', 'lon'],
#       dtype='object')

# %%
combined.head(20)
# Out:
#     index     dbn test_takers_count  avg_reading_score  avg_math_score  \
# 0       0  01M292                29              355.0           404.0
# 1       1  01M448                91              383.0           423.0
# 2       2  01M450                70              377.0           402.0
# 3       3  01M509                44              390.0           433.0
# 4       4  01M539               159              522.0           574.0
# 5       5  01M696               130              624.0           604.0
# 6       6  02M047                16              395.0           400.0
# 7       7  02M288                62              409.0           393.0
# 8       8  02M294                53              394.0           384.0
# 9       9  02M296                58              374.0           375.0
# 10     10  02M298                85              423.0           438.0
# 11     11  02M300                48              404.0           449.0
# 12     12  02M303                76              353.0           358.0
# 13     13  02M305                50              375.0           388.0
# 14     14  02M308                40              403.0           392.0
# 15     15  02M316                42              373.0           370.0
# 16     16  02M374                60              391.0           391.0
# 17     17  02M376                92              473.0           483.0
# 18     21  02M400               263              465.0           493.0
# 19     22  02M407                54              492.0           465.0
#
#     avg_writing_score  avg_total_score  ap_test_takers  total_exams_taken  \
# 0               363.0           1122.0             NaN                NaN
# 1               366.0           1172.0            39.0               49.0
# 2               370.0           1149.0            19.0               21.0
# 3               384.0           1207.0             NaN                NaN
# 4               525.0           1621.0           255.0              377.0
# 5               628.0           1856.0             NaN                NaN
# 6               387.0           1182.0             NaN                NaN
# 7               392.0           1194.0             NaN                NaN
# 8               378.0           1156.0             NaN                NaN
# 9               362.0           1111.0             NaN                NaN
# 10              432.0           1293.0            21.0               21.0
# 11              416.0           1269.0            99.0              117.0
# 12              340.0           1051.0            42.0               44.0
# 13              385.0           1148.0            25.0               37.0
# 14              405.0           1200.0             NaN                NaN
# 15              384.0           1127.0             NaN                NaN
# 16              394.0           1176.0             NaN                NaN
# 17              479.0           1435.0             NaN                NaN
# 18              461.0           1419.0           213.0              298.0
# 19              467.0           1424.0             NaN                NaN
#
#     #_exams_with_high_scores   demographic  \
# 0                        NaN  Total Cohort
# 1                       10.0  Total Cohort
# 2                        NaN  Total Cohort
# 3                        NaN  Total Cohort
# 4                      191.0  Total Cohort
# 5                        NaN  Total Cohort
# 6                        NaN  Total Cohort
# 7                        NaN  Total Cohort
# 8                        NaN  Total Cohort
# 9                        NaN  Total Cohort
# 10                       NaN  Total Cohort
# 11                      10.0  Total Cohort
# 12                       NaN  Total Cohort
# 13                      15.0  Total Cohort
# 14                       NaN  Total Cohort
# 15                       NaN  Total Cohort
# 16                       NaN  Total Cohort
# 17                       NaN           NaN
# 18                     152.0  Total Cohort
# 19                       NaN  Total Cohort
#
#                                           school_name cohort  total_cohort  \
# 0               Henry Street School For International   2006          78.0
# 1                 University Neighborhood High School   2006         124.0
# 2                          East Side Community School   2006          90.0
# 3                             Marta Valle High School   2006          84.0
# 4               New Explorations Into Science  Techno   2006          46.0
# 5                      Bard High School Early College   2006         139.0
# 6               47 The American Sign Language And Eng   2006          25.0
# 7                        Food And Finance High School   2006         102.0
# 8                                Essex Street Academy   2006          89.0
# 9               High School Of Hospitality Management   2006          75.0
# 10                                   Pace High School   2006          92.0
# 11              Urban Assembly School Of Design And C   2006          80.0
# 12                         Facing History School  The   2006          71.0
# 13               Urban Assembly Academy Of Government   2006          61.0
# 14                       Lower Manhattan Arts Academy   2006          68.0
# 15  Urban Assembly School Of Business For Young Women   2006          72.0
# 16                          Gramercy Arts High School   2006          93.0
# 17                                                NaN    NaN           NaN
# 18              High School For Environmental Studies   2006         352.0
# 19              Institute For Collaborative Education   2006          55.0
#
#     total_grads_n  total_grads_%_cohort  total_regents_n  \
# 0            43.0                  55.1             36.0
# 1            53.0                  42.7             42.0
# 2            70.0                  77.8             67.0
# 3            47.0                  56.0             40.0
# 4            46.0                 100.0             46.0
# 5           134.0                  96.4            134.0
# 6            19.0                  76.0              8.0
# 7            91.0                  89.2             77.0
# 8            64.0                  71.9             58.0
# 9            58.0                  77.3             50.0
# 10           78.0                  84.8             76.0
# 11           49.0                  61.3             45.0
# 12           34.0                  47.9             34.0
# 13           46.0                  75.4             40.0
# 14           46.0                  67.6             32.0
# 15           53.0                  73.6             44.0
# 16           68.0                  73.1             51.0
# 17            NaN                   NaN              NaN
# 18          262.0                  74.4            219.0
# 19           42.0                  76.4              0.0
#
#     total_regents_%_cohort  total_regents_%_grads  advanced_regents_n  \
# 0                     46.2                   83.7                 0.0
# 1                     33.9                   79.2                 8.0
# 2                     74.4                   95.7                 0.0
# 3                     47.6                   85.1                17.0
# 4                    100.0                  100.0                31.0
# 5                     96.4                  100.0                 0.0
# 6                     32.0                   42.1                 0.0
# 7                     75.5                   84.6                 0.0
# 8                     65.2                   90.6                 0.0
# 9                     66.7                   86.2                 1.0
# 10                    82.6                   97.4                39.0
# 11                    56.3                   91.8                 0.0
# 12                    47.9                  100.0                 0.0
# 13                    65.6                   87.0                 0.0
# 14                    47.1                   69.6                 1.0
# 15                    61.1                   83.0                 8.0
# 16                    54.8                   75.0                 1.0
# 17                     NaN                    NaN                 NaN
# 18                    62.2                   83.6                80.0
# 19                     0.0                    0.0                 0.0
#
#     advanced_regents_%_cohort  advanced_regents_%_grads  \
# 0                         0.0                       0.0
# 1                         6.5                      15.1
# 2                         0.0                       0.0
# 3                        20.2                      36.2
# 4                        67.4                      67.4
# 5                         0.0                       0.0
# 6                         0.0                       0.0
# 7                         0.0                       0.0
# 8                         0.0                       0.0
# 9                         1.3                       1.7
# 10                       42.4                      50.0
# 11                        0.0                       0.0
# 12                        0.0                       0.0
# 13                        0.0                       0.0
# 14                        1.5                       2.2
# 15                       11.1                      15.1
# 16                        1.1                       1.5
# 17                        NaN                       NaN
# 18                       22.7                      30.5
# 19                        0.0                       0.0
#
#     regents_w/o_advanced_n  regents_w/o_advanced_%_cohort  \
# 0                     36.0                           46.2
# 1                     34.0                           27.4
# 2                     67.0                           74.4
# 3                     23.0                           27.4
# 4                     15.0                           32.6
# 5                    134.0                           96.4
# 6                      8.0                           32.0
# 7                     77.0                           75.5
# 8                     58.0                           65.2
# 9                     49.0                           65.3
# 10                    37.0                           40.2
# 11                    45.0                           56.3
# 12                    34.0                           47.9
# 13                    40.0                           65.6
# 14                    31.0                           45.6
# 15                    36.0                           50.0
# 16                    50.0                           53.8
# 17                     NaN                            NaN
# 18                   139.0                           39.5
# 19                     0.0                            0.0
#
#     regents_w/o_advanced_%_grads  ...    N_p  nr_s  nr_t  nr_p  saf_p_11  \
# 0                           83.7  ...  151.0   425    37   389       7.8
# 1                           64.2  ...   46.0   459    39   445       7.9
# 2                           95.7  ...  150.0   566    43   534       8.7
# 3                           48.9  ...   69.0   339    28   325       7.7
# 4                           32.6  ...  736.0   945    98  1446       8.5
# 5                          100.0  ...  283.0   571    37   561       8.8
# 6                           42.1  ...   43.0   152    21   145       8.9
# 7                           84.6  ...  229.0   407    31   405       7.6
# 8                           90.6  ...   28.0   314    27   306       8.7
# 9                           84.5  ...  204.0   385    28   365       8.0
# 10                          47.4  ...  184.0   407    29   401       7.5
# 11                          91.8  ...  124.0   381    27   366       8.6
# 12                         100.0  ...  200.0   386    36   377       8.2
# 13                          87.0  ...   12.0   273    19   268       7.5
# 14                          67.4  ...   45.0   307    24   299       7.8
# 15                          67.9  ...  206.0   341    22   335       8.4
# 16                          73.5  ...  264.0   448    34   450       8.2
# 17                           NaN  ...  114.0   312    19   308       8.6
# 18                          53.1  ...  323.0  1383    71  1351       8.3
# 19                           0.0  ...  203.0   487    27   450       8.3
#
#     com_p_11  eng_p_11  aca_p_11  saf_t_11  com_t_11  eng_t_11  aca_t_11  \
# 0        7.7       7.4       7.6       6.3       5.3       6.1       6.5
# 1        7.4       7.2       7.3       6.6       5.8       6.6       7.3
# 2        8.2       8.1       8.4       7.3       8.0       8.0       8.8
# 3        7.4       7.2       7.3       6.4       5.3       6.1       6.8
# 4        7.9       7.9       8.4       7.6       5.6       5.9       7.3
# 5        8.2       8.3       9.1       8.2       7.4       7.5       8.3
# 6        7.7       7.9       8.1       8.1       6.1       7.7       7.2
# 7        7.0       6.9       7.6       7.3       7.1       7.8       7.7
# 8        8.1       7.9       8.3       8.0       7.7       7.9       8.9
# 9        7.3       7.1       7.5       8.6       8.1       8.7       8.9
# 10       7.1       6.9       7.5       6.6       6.3       6.8       7.1
# 11       7.9       7.7       8.1       7.3       6.0       6.9       7.5
# 12       7.8       7.6       8.0       7.4       7.4       7.7       7.9
# 13       7.4       7.3       7.7       5.4       4.3       5.8       6.0
# 14       7.4       7.3       7.4       7.4       7.5       7.7       8.0
# 15       7.6       7.5       7.9       7.0       6.2       6.5       7.4
# 16       7.6       7.7       8.1       6.4       5.5       6.7       6.7
# 17       8.3       7.8       8.0       7.7       6.5       6.8       7.4
# 18       7.6       7.6       7.7       7.3       6.4       7.1       7.4
# 19       8.2       8.2       8.5       8.1       8.1       8.8       9.0
#
#     saf_s_11  com_s_11 eng_s_11  aca_s_11  saf_tot_11  com_tot_11  eng_tot_11  \
# 0        6.0       5.6      6.1       6.7         6.7         6.2         6.6
# 1        6.0       5.7      6.3       7.0         6.8         6.3         6.7
# 2        NaN       NaN      NaN       NaN         7.9         7.9         7.9
# 3        6.4       5.9      6.4       7.0         6.9         6.2         6.6
# 4        7.3       6.4      7.0       7.7         7.8         6.7         6.9
# 5        8.3       7.3      8.0       8.9         8.5         7.6         8.0
# 6        7.3       6.3      7.0       7.5         8.1         6.7         7.5
# 7        6.2       5.7      6.1       7.2         7.0         6.6         6.9
# 8        7.4       6.5      7.3       7.6         7.9         7.3         7.7
# 9        7.1       6.5      7.0       7.4         7.9         7.3         7.6
# 10       6.6       6.2      6.7       7.5         6.9         6.6         6.8
# 11       6.5       5.7      6.1       7.2         7.5         6.5         6.9
# 12       7.0       6.6      6.8       7.4         7.5         7.3         7.3
# 13       6.0       6.0      6.0       7.2         6.1         5.6         6.2
# 14       6.6       5.8      6.7       7.3         7.3         6.9         7.2
# 15       6.8       6.4      6.7       7.6         7.4         6.7         6.9
# 16       6.1       6.0      6.3       7.2         6.9         6.4         6.9
# 17       7.8       7.0      7.6       8.1         8.0         7.3         7.4
# 18       7.1       6.2      7.0       7.8         7.6         6.7         7.2
# 19       7.5       7.8      7.9       8.3         8.0         8.0         8.3
#
#     aca_tot_11    zip  total_students  \
# 0          7.0  10002           323.0
# 1          7.2  10002           299.0
# 2          8.4  10009           649.0
# 3          7.0  10002           401.0
# 4          7.8  10002          1725.0
# 5          8.7  10002           560.0
# 6          7.6  10010           184.0
# 7          7.5  10019           443.0
# 8          8.2  10002           349.0
# 9          8.0  10019           431.0
# 10         7.4  10002           421.0
# 11         7.6  10019           427.0
# 12         7.8  10019           417.0
# 13         6.8  10002           326.0
# 14         7.6  10002           362.0
# 15         7.6  10004           412.0
# 16         7.4  10003           548.0
# 17         7.9  10013           433.0
# 18         7.6  10019          1312.0
# 19         8.6  10003           468.0
#
#                                            Location 1        lat        lon
# 0   220 Henry Street\nNew York, NY 10002\n(40.7137...  40.713764 -73.985260
# 1   200 Monroe Street\nNew York, NY 10002\n(40.712...  40.712332 -73.984797
# 2   420 East 12 Street\nNew York, NY 10009\n(40.72...  40.729783 -73.983041
# 3   145 Stanton Street\nNew York, NY 10002\n(40.72...  40.720569 -73.985673
# 4   111 Columbia Street\nNew York, NY 10002\n(40.7...  40.718725 -73.979426
# 5   525 East Houston Street\nNew York, NY 10002\n(...  40.718962 -73.976066
# 6   223 East 23 Street\nNew York, NY 10010\n(40.73...  40.738599 -73.982512
# 7   525 West 50Th Street\nNew York, NY 10019\n(40....  40.765027 -73.992517
# 8   350 Grand Street\nNew York, NY 10002\n(40.7168...  40.716867 -73.989532
# 9   525 West 50Th Street\nNew York, NY 10019\n(40....  40.765027 -73.992517
# 10  100 Hester Street\nNew York, NY 10002\n(40.716...  40.716412 -73.992676
# 11  525 West 50Th Street\nNew York, NY 10019\n(40....  40.765027 -73.992517
# 12  525 West 50Th Street\nNew York, NY 10019\n(40....  40.765027 -73.992517
# 13  350 Grand Street\nNew York, NY 10002\n(40.7168...  40.716867 -73.989532
# 14  350 Grand Street\nNew York, NY 10002\n(40.7168...  40.716867 -73.989532
# 15  26 Broadway\nNew York, NY 10004\n(40.705234939...  40.705235 -74.013315
# 16  40 Irving Place\nNew York, NY 10003\n(40.73551...  40.735519 -73.987604
# 17  131 Avenue Of The Americas\nNew York, NY 10013...  40.724353 -74.004759
# 18  444 West 56 Street\nNew York, NY 10019\n(40.76...  40.767762 -73.987511
# 19  345 East 15Th Street\nNew York, NY 10003\n(40....  40.732485 -73.983053
#
# [20 rows x 84 columns]

# %% [markdown]
# Most of the null data has been removed. We lost nearly 8% of the dataset after removing the schools with not SAT scores. Seeing as SAT scores are important to our assessment this loss could be considered as small. We shall now begin analysis of the data.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 4

# %% [markdown]
# ## Reading and Combining the Data

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 5

# %% [markdown]
# ## And how are you related?

# %% [markdown]
# **Understanding the correlations between the SAT score and other columns**

# %% [markdown]
# Now that all the data is combined it will be easier to assess how the various columns related to SAT-score columns. We begin by assessing the correlation between the different columns in the _combined_ dataframe. We can then pick certain strong correlation and explore the impact on SAT scores

# %%
corr_frame = combined.corr()
corr_frame.head(3)
# Out:
#                       index  avg_reading_score  avg_math_score  \
# index              1.000000          -0.005028        0.039061
# avg_reading_score -0.005028           1.000000        0.929136
# avg_math_score     0.039061           0.929136        1.000000
#
#                    avg_writing_score  avg_total_score  ap_test_takers  \
# index                      -0.031269         0.002173        0.118754
# avg_reading_score           0.983013         0.986798        0.580034
# avg_math_score              0.932029         0.972696        0.636746
#
#                    total_exams_taken  #_exams_with_high_scores  total_cohort  \
# index                       0.096995                  0.021144      0.316586
# avg_reading_score           0.572409                  0.585638      0.265597
# avg_math_score              0.622612                  0.632692      0.361513
#
#                    total_grads_n  total_grads_%_cohort  total_regents_n  \
# index                   0.290338             -0.028687         0.263567
# avg_reading_score       0.394940              0.620575         0.451125
# avg_math_score          0.479483              0.579396         0.533550
#
#                    total_regents_%_cohort  total_regents_%_grads  \
# index                           -0.023752              -0.022094
# avg_reading_score                0.668447               0.454679
# avg_math_score                   0.657423               0.485500
#
#                    advanced_regents_n  advanced_regents_%_cohort  \
# index                        0.164474                   0.084098
# avg_reading_score            0.556181                   0.751242
# avg_math_score               0.635323                   0.816473
#
#                    advanced_regents_%_grads  regents_w/o_advanced_n  \
# index                              0.119859                0.294159
# avg_reading_score                  0.714160                0.157147
# avg_math_score                     0.794113                0.214203
#
#                    regents_w/o_advanced_%_cohort  \
# index                                  -0.132453
# avg_reading_score                      -0.115744
# avg_math_score                         -0.209492
#
#                    regents_w/o_advanced_%_grads   local_n  local_%_cohort  \
# index                                 -0.149017  0.316107        0.003864
# avg_reading_score                     -0.431562 -0.064424       -0.410453
# avg_math_score                        -0.495474 -0.002693       -0.452708
#
#                    local_%_grads  still_enrolled_n  still_enrolled_%_cohort  \
# index                   0.022094          0.311532                 0.077976
# avg_reading_score      -0.454679         -0.037739                -0.527053
# avg_math_score         -0.485500          0.063175                -0.485835
#
#                    ...       N_t       N_p      nr_s      nr_t      nr_p  \
# index              ...  0.253837  0.189243  0.259393  0.242976  0.249756
# avg_reading_score  ...  0.252165  0.383563  0.316900  0.270526  0.331405
# avg_math_score     ...  0.352115  0.467481  0.412617  0.368456  0.425522
#
#                    saf_p_11  com_p_11  eng_p_11  aca_p_11  saf_t_11  com_t_11  \
# index             -0.195469 -0.097272 -0.051710 -0.094120 -0.003820  0.127686
# avg_reading_score  0.111563 -0.123552  0.028663  0.035286  0.311513  0.085483
# avg_math_score     0.124642 -0.124357  0.013185  0.031737  0.360436  0.091197
#
#                    eng_t_11  aca_t_11  saf_s_11  com_s_11  eng_s_11  aca_s_11  \
# index              0.069739  0.085986 -0.129054 -0.097612 -0.008022 -0.062008
# avg_reading_score  0.038140  0.135595  0.310443  0.187459  0.196210  0.330603
# avg_math_score     0.049038  0.161992  0.388096  0.216729  0.253777  0.361252
#
#                    saf_tot_11  com_tot_11  eng_tot_11  aca_tot_11       zip  \
# index               -0.117173    0.020766    0.026062    0.003397  0.844304
# avg_reading_score    0.302657    0.077888    0.101094    0.194760 -0.078191
# avg_math_score       0.361182    0.091435    0.122019    0.212337 -0.043318
#
#                    total_students       lat       lon
# index                    0.263870 -0.521505  0.303723
# avg_reading_score        0.366737 -0.123796 -0.137651
# avg_math_score           0.462106 -0.138668 -0.129165
#
# [3 rows x 77 columns]

# %%
fig,ax = plt.subplots(figsize=(25,5))
sns.heatmap(corr_frame.iloc[0:4,4:25],annot=True)
ax.tick_params(axis='x',labelsize=20,rotation=75)
ax.tick_params(axis='y',labelsize=20)
plt.title("SAT vs. Adv. Placement & Graduation",size=22)
plt.show()

# %% [markdown]
# Based on the graduation and advanced placement data we shall explore the relationship if any of:
# - The impact of number of Advanced Placement test takers on SAT scores. (_ap_test_takers_)
# - The impact of the percentage of graduates locally on SAT scores (_local_%_grads_)

# %%
fig,ax = plt.subplots(figsize=(25,5))
sns.heatmap(corr_frame.iloc[0:4,25:35],annot=True)
ax.tick_params(axis='x',labelsize=20,rotation=65)
ax.tick_params(axis='y',labelsize=20)
plt.title("SAT vs. Class Size",size=22)
plt.show()

# %% [markdown]
# For this we shall explore the impact on SAT scores by:
# - Average Class Size (_avg_class_size_)
# - Average pupil teacher ratio(_avg_pupil_teacher_ratio_)

# %%
fig,ax = plt.subplots(figsize=(25,5))
sns.heatmap(corr_frame.iloc[0:4,35:47],annot=True)
ax.tick_params(axis='x',labelsize=20,rotation=75)
ax.tick_params(axis='y',labelsize=20)
plt.title("SAT vs. Demographic",size=22)
plt.show()

# %% [markdown]
# Based on the heatmap we shall explore the impact of the different ethnicities on the SAT scores

# %%
fig,ax = plt.subplots(figsize=(25,5))
sns.heatmap(corr_frame.iloc[0:4,47:65],annot=True)
ax.tick_params(axis='x',labelsize=20,rotation=75)
ax.tick_params(axis='y',labelsize=20)
ax.tick_params(axis='y',labelsize=20)
plt.show()

# %% [markdown]
# Apart from safety factors like communication, engagement and academic expectations do not seem to have a significant impact on SAT scores.We shall have to explore this in a different manner.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 5

# %% [markdown]
# ## SAT vs. A.P & Graduation

# %% [markdown]
# Earlier, we identified a single column from both the Advanced Placement data and the Graduation data for analysis on SAT scores. The columns were _local_%_grads_ and _ap_test_takers_ .
#
# It must be noted at this juncture that this is merely an exploration. It may reveal insights that are impactful or that have no meaning. The result can only come out through analysis.
#
# The correlation between the above columns and the average total SAT score were 0.61 and -0.48 respectively. We shall begin our analysis by plotting scatter plots to visualize these correlations.

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,5))

#ax1 = fig.add_subplot(1,2,1)
ax1.scatter(x=combined['ap_test_takers'],y=combined['avg_total_score'],color='#47D990')
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.xaxis.tick_top()
ax1.set_ylabel("Avg. SAT Score",size=17,rotation=90)
ax1.set_xlim([0,combined['ap_test_takers'].max()])
ax1.set_ylim([1000,combined['avg_total_score'].max()])
ax1.set_title("No. of AP Test Takers",size=20,loc="center")
ax1.axvline(x=325,alpha=0.2,linestyle="dashed")

#ax2 = fig.add_subplot(1,2,2)
ax2.scatter(x=combined['local_%_grads'],y=combined['avg_total_score'],color='#DA8FBE')
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.xaxis.tick_top()
ax2.tick_params(axis='y',left=False,labelleft=False)
ax2.set_xlim([0,100])
#ax1.set_ylim([1000,combined['avg_total_score'].max()])
ax2.set_title("Local Graduates (%)", size=20, loc="center")

plt.suptitle("Impact on SAT Scores", size=22)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# While the correlation of number of test takers is positive. The number of test takers per school is less than 275 in most schools. There are only a few schools that have more than 275 AP test takers and from those there are a few whose scores are less than 1600.

# %%
print('\033[1m' + "Schools with greater than 275 AP test takers and their SAT scores" + '\033[0m')
combined[combined['ap_test_takers']>275][['school_name','ap_test_takers','avg_total_score']].sort_values('avg_total_score',ascending=False)
# Out:
# Schools with greater than 275 AP test takers and their SAT scores
#                                school_name  ap_test_takers  avg_total_score
# 33                  Stuyvesant High School          1510.0           2096.0
# 137           Bronx High School Of Science          1190.0           1969.0
# 329    Staten Island Technical High School           528.0           1953.0
# 280            Townsend Harris High School           613.0           1910.0
# 171         Brooklyn Technical High School          2117.0           1833.0
# 54    Fiorello H. Laguardia High School Of           691.0           1707.0
# 256  Leon M. Goldstein High School For The           367.0           1627.0
# 282        Benjamin N. Cardozo High School           676.0           1514.0
# 283              Francis Lewis High School           697.0           1474.0
# 254                    Midwood High School           745.0           1473.0
# 285                    Bayside High School           480.0           1449.0
# 248           Edward R. Murrow High School           397.0           1431.0
# 60   Manhattan Center For Science And Math           328.0           1430.0
# 326                Tottenville High School           396.0           1418.0
# 298               Forest Hills High School           733.0           1407.0
# 327            Susan E. Wagner High School           279.0           1388.0
# 255              James Madison High School           323.0           1350.0
# 242              Fort Hamilton High School           357.0           1306.0
# 135             Dewitt Clinton High School           366.0           1255.0
# 98           Herbert H. Lehman High School           430.0           1241.0
# 314           Long Island City High School           406.0           1218.0
# 279                   Flushing High School           324.0           1216.0

# %% [markdown]
# The percentage of local graduates seems to have a negative correlation to the SAT score. However, it must be noted that the correlation, increase in the number of graduates decreases  the SAT scores seems logically absurd. Moreover, a student becomes a graduate after passing the SAT, so the percentage of local graduates impacting SAT seems inconsistent.
#
# Both of the above look like cases of correlation not implying causation.
#
# Based on these assumptions we shall be abandoning this analysis.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 6

# %% [markdown]
# ## SAT vs. Class Size

# %% [markdown]
# Next, we shall analyze the impact from the *Class Size* dataset. The following columns were selected for exploration.
# - Average Class Size (avg_class_size)
# - Average pupil teacher ratio(avg_pupil_teacher_ratio)
#
# The correlations identified for the above columns on the impact on SAT is 0.38 and 0.47 respectively. We shall plot these correlations below.

# %%
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,5))

#ax1 = fig.add_subplot(1,2,1)
ax1.scatter(x=combined['avg_class_size'],y=combined['avg_total_score'],color='#880ED4')
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.xaxis.tick_top()
ax1.set_ylabel("Avg. SAT Score",size=17,rotation=90)
ax1.set_xlim([10,combined['avg_class_size'].max()])
ax1.set_ylim([1000,combined['avg_total_score'].max()])
ax1.set_title("Average Class Size",size=20,loc="center")
#ax1.axvline(x=325,alpha=0.2,linestyle="dashed")

#ax2 = fig.add_subplot(1,2,2)
ax2.scatter(x=combined['avg_pupil_teacher_ratio'],y=combined['avg_total_score'],color='#0085FF')
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.xaxis.tick_top()
ax2.tick_params(axis='y',left=False,labelleft=False)
ax2.set_xlim([9,combined['avg_pupil_teacher_ratio'].max()])
#ax1.set_ylim([1000,combined['avg_total_score'].max()])
ax2.set_title("Pupil-Teacher Ratio", size=20, loc="center")

plt.suptitle("Impact on SAT Scores", size=22)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# *average_class_size* does not seem to have a clear positive correlation as there are a number of schools with big class sizes but still low scores. We shall still further analyze this.
#
# *pupil-teacher ratio* seems to have a clear positive correlation. We shall analyze this as well.
# We shall carry out analysis for both parameter by selecting 5 schools with the best SAT scores and 5 schools with the worst SAT scores and find out the impact on SAT scores versus their values for the above mentioned parameters.

# %%
sort_by_sat = combined.sort_values('avg_total_score')
best_worst = pd.concat([sort_by_sat.head(),sort_by_sat.tail()])

# %%
best_worst[best_worst['school_name'].isnull()]
# Out:
#      index     dbn test_takers_count  avg_reading_score  avg_math_score  \
# 233    255  19K583                29              279.0           322.0
# 81      92  07X334                34              310.0           324.0
#
#      avg_writing_score  avg_total_score  ap_test_takers  total_exams_taken  \
# 233              286.0            887.0            44.0               44.0
# 81               311.0            945.0             NaN                NaN
#
#      #_exams_with_high_scores demographic school_name cohort  total_cohort  \
# 233                      39.0         NaN         NaN    NaN           NaN
# 81                        NaN         NaN         NaN    NaN           NaN
#
#      total_grads_n  total_grads_%_cohort  total_regents_n  \
# 233            NaN                   NaN              NaN
# 81             NaN                   NaN              NaN
#
#      total_regents_%_cohort  total_regents_%_grads  advanced_regents_n  \
# 233                     NaN                    NaN                 NaN
# 81                      NaN                    NaN                 NaN
#
#      advanced_regents_%_cohort  advanced_regents_%_grads  \
# 233                        NaN                       NaN
# 81                         NaN                       NaN
#
#      regents_w/o_advanced_n  regents_w/o_advanced_%_cohort  \
# 233                     NaN                            NaN
# 81                      NaN                            NaN
#
#      regents_w/o_advanced_%_grads  ...    N_p  nr_s  nr_t  nr_p  saf_p_11  \
# 233                           NaN  ...   39.0   402    24   353       7.9
# 81                            NaN  ...  102.0   354    26   316       8.6
#
#      com_p_11  eng_p_11  aca_p_11  saf_t_11  com_t_11  eng_t_11  aca_t_11  \
# 233       8.1       7.5       7.8       6.1       5.6       5.9       6.3
# 81        8.2       7.8       8.1       7.8       5.6       7.4       7.5
#
#      saf_s_11  com_s_11 eng_s_11  aca_s_11  saf_tot_11  com_tot_11  \
# 233       7.1       5.9      7.0       7.4         7.0         6.5
# 81        7.3       6.5      7.0       7.5         7.9         6.8
#
#      eng_tot_11  aca_tot_11    zip  total_students  \
# 233         6.8         7.1  11208           322.0
# 81          7.4         7.7  10454           437.0
#
#                                             Location 1        lat        lon
# 233  999 Jamaica Avenue\nBrooklyn, NY 11208\n(40.69...  40.691144 -73.868426
# 81   345 Brook Avenue\nBronx, NY 10454\n(40.8100361...  40.810036 -73.917812
#
# [2 rows x 84 columns]

# %% [markdown]
# There are two schools for which the school names are not available. We shall have to identify the schools names by googling the values in *Location 1*.

# %%
best_worst.loc[233,'school_name'] = 'Multicultural High School'
best_worst.loc[81,'school_name'] =  'International Community High School'

# %%
fig=plt.figure(figsize=(10,5))
bar_colors=['#D0C06E','grey','grey','grey','grey','grey','grey','grey','grey','#30D5C8']

#Class Size plot
ax1 = fig.add_subplot(1,2,1)
ax1.xaxis.tick_top()

#Plot Class Size plot
for each_key in ax1.spines.keys():
    ax1.spines[each_key].set_visible(False)
sns.barplot(y=best_worst['school_name'],x=best_worst['avg_class_size'],palette=bar_colors)

#Customize Class Size plot
ax1.tick_params(axis='y',left=False,labelsize=13)
ax1.tick_params(axis='x',top=False,labeltop=False)
ax1.set_ylabel(None)
ax1.set_xlabel(None)

#Annotate Class Size plot
for i,p in zip(range(10),ax1.patches):
    x=p.get_x()+p.get_width()
    y=p.get_y()+p.get_height()
    i+=1
    if i in [1,10]:
        ax1.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',weight='bold')
    else:
        ax1.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',alpha=0.3)
ax1.set_title('Average Class Size',size=20,loc='center')

#------
#SAT score plot
ax2 = fig.add_subplot(1,2,2)
ax2.xaxis.tick_top()

#Plot SAT score
for each_key in ax2.spines.keys():
    ax2.spines[each_key].set_visible(False)
sns.barplot(y=best_worst['school_name'],x=best_worst['avg_total_score'],palette=bar_colors)

#Customize SAT score plot
ax2.tick_params(left=False,top=False,labelleft=False,labeltop=False)
ax2.set_ylabel(None)
ax2.set_xlabel(None)

#Annotate SAT Plot
for i,p in zip(range(10),ax2.patches):
    x=p.get_x()+p.get_width()
    y=p.get_y()+p.get_height()
    i+=1
    if i in [1,10]:
        ax2.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',weight='bold')
    else:
        ax2.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',alpha=0.3)
#------

#Set plot title
ax2.set_title('Average SAT Score',size=20,loc='center')

#Figure title
plt.suptitle("Class Size vs SAT Scores in Worst to Best School", size=22,x=0.65)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# As illustrated above there are schools with small class sizes and higher SAT scores. The relationship also exists the other way round wherein there are schools with large class sizes and lesser scores.
#
# After [researching](https://www.insidehighered.com/news/2020/06/18/study-some-things-matter-more-class-size-when-it-comes-student-success) on the impact further we find that the impact of class size is not as much as one would expect. There are other factors like the social group a student belongs to and the mode of delivery that need to be taken in to consideration.

# %% [markdown]
# We can now move on to verifying the impact of Pupil-teacher ratio in the same manner as we verified the impact of class size.

# %%
fig=plt.figure(figsize=(10,5))
bar_colors=['#93E9BE','grey','grey','grey','grey','grey','grey','grey','grey','#125734']

#Pupil-teacher ratio plot
ax1 = fig.add_subplot(1,2,1)
ax1.xaxis.tick_top()
for each_key in ax1.spines.keys():
    ax1.spines[each_key].set_visible(False)
    
#Plot the pupil-teacher ratio
sns.barplot(y=best_worst['school_name'],x=best_worst['avg_pupil_teacher_ratio'],palette=bar_colors)

#Customize pupil-teacher ratio plot
ax1.tick_params(axis='y',left=False,labelsize=13)
ax1.tick_params(axis='x',top=False,labeltop=False)
ax1.set_ylabel(None)
ax1.set_xlabel(None)

#Annotate pupil-teacher ratio  plot
for i,p in zip(range(10),ax1.patches):
    x=p.get_x()+p.get_width()
    y=p.get_y()+p.get_height()
    i+=1
    if i in [1,10]:
        ax1.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',weight='bold')
    else:
        ax1.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',alpha=0.3)
ax1.set_title('Pupil-Teacher Ratio',size=20,loc='center')
#------

#SAT plot
ax2 = fig.add_subplot(1,2,2)
ax2.xaxis.tick_top()
for each_key in ax2.spines.keys():
    ax2.spines[each_key].set_visible(False)

#Plot the SAT score 
sns.barplot(y=best_worst['school_name'],x=best_worst['avg_total_score'],palette=bar_colors)

#Customize the SAT plot
ax2.tick_params(left=False,top=False,labelleft=False,labeltop=False)
ax2.set_ylabel(None)
ax2.set_xlabel(None)

#Annotate the SAT plot
for i,p in zip(range(10),ax2.patches):
    x=p.get_x()+p.get_width()
    y=p.get_y()+p.get_height()
    i+=1
    if i in [1,10]:
        ax2.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',weight='bold')
    else:
        ax2.annotate(text=p.get_width(),xy=(x,y),xytext=(0,9),textcoords='offset points',alpha=0.3)
ax2.set_title('Average SAT Score',size=20,loc='center')

# Best to Worst indicator
#ax2.arrow(x=2800,y=0,dx=0,dy=2,head_length=0.03,alpha=0.3)
#------

#Figure plot
plt.suptitle("Pupil-Teacher Ratio vs SAT in the Worst and Best Schools", size=22,x=0.65)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# While analysing this parameter, student-teacher ratio does seem to be a [compelling factor](https://www.publicschoolreview.com/blog/how-important-is-the-student-teacher-ratio-for-students) that affects SAT scores. However, here in it must be noted that other factors including resources provided by the school also play a significant role in helping teacher to achieve higher SAT scores from students.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 7

# %% [markdown]
# ## SAT vs. Demographic

# %% [markdown]
# We shall review the impact of the four races on SAT scores.

# %%
print('\033[1m' + "Correlation of SAT score and the different races of students" + '\033[0m')
corr_frame.loc["avg_total_score","asian_per":"white_per"]
# Out:
# Correlation of SAT score and the different races of students
# asian_per       0.587625
# black_num       0.022858
# black_per      -0.298562
# hispanic_num    0.021649
# hispanic_per   -0.416839
# white_num       0.453184
# white_per       0.644049
# Name: avg_total_score, dtype: float64

# %% [markdown]
# Caucasians and Asians seem to have a positive correlation while African americans and Hispanics seem to have a negative correlation with relation to SAT score.

# %% [markdown]
# A better understanding of these results could be highlighted using scatter plots.

# %%
color = ['#009292','#F65156','#88070B','#FFCE13']
title = ['Asian', 'Black', 'Hispanic', 'White']
race = ['asian_per','black_per','hispanic_per','white_per']
fig,((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(11,7))
axes = [ax1,ax2,ax3,ax4]

#Plot the correlations for each race
for ax,a_race in zip(axes,range(0,4)):
    for each_key in ax.spines.keys():
        ax.spines[each_key].set_visible(False)
#Draw the scatter plots
    ax.scatter(combined[race[a_race]],combined['avg_total_score'],c=color[a_race])
    ax.set_title('{} students (%)'.format(title[a_race]),size=20)

# Asian students plot
ax1.tick_params(axis ='x',top=True,labeltop=True,
                bottom=False,labelbottom=False,
                labelsize=15)
ax1.tick_params(axis ='y',labelsize=15)
ax1.xaxis.tick_top()

ax1.set_xlim([0,100])
ax1.set_ylim([combined['avg_total_score'].min(),combined['avg_total_score'].max()])

# Black students plot
ax2.tick_params(axis ='x',top=True,labeltop=True,
                bottom=False,labelbottom=False,
                labelsize=15)
ax2.tick_params(axis ='y',left=False,labelleft=False)
ax2.set_xlim([0,100])
ax2.xaxis.tick_top()

#Hispanic students plot
ax3.tick_params(axis ='x',bottom=False,labelbottom=False)
ax3.tick_params(axis ='y',labelsize=15)
ax3.set_ylim([combined['avg_total_score'].min(),combined['avg_total_score'].max()])

#White students plot
ax4.tick_params(axis ='x',top=False,labeltop=False,
                bottom=False,labelbottom=False)
ax4.tick_params(axis ='y',left=False,labelleft=False)

#Figure title
plt.suptitle("SAT score vs Racial Profile",size=22)
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# **Observation**
# - The plots clearly reflect the positive and negative correlations observed earlier.
# - Black and hispanic students have marginal representations in institutions with high SAT scores.
# - Hispanic students seem to suffer the brunt of this disparity considering that they have almost 100% representation in schools that have average SAT scores much less than 1000
# - Black students have almost 0 representation in schools with very high SAT scores.
# - The presence of white and asian students are significant in schools that have high SAT scores.

# %% [markdown]
# To understand the obseravation further it would be good to delve in to the institutions themselves and find how they perform.

# %%
# Schools that have more than 95% hispanic students and their average SAT scores.
print('\033[1m' + "Average SAT scores of schools having greater than 95% Hispanic students" + '\033[0m')
combined[combined['hispanic_per'] > 95][['school_name','avg_total_score']]
# Out:
# Average SAT scores of schools having greater than 95% Hispanic students
#                                school_name  avg_total_score
# 40           Manhattan Bridges High School           1058.0
# 73                                     NaN           1174.0
# 79   Gregorio Luperon High School For Scie           1014.0
# 111                                    NaN            951.0
# 127  International School For Liberal Arts            934.0
# 162                                    NaN            970.0
# 233                                    NaN            887.0
# 264                                    NaN            951.0

# %% [markdown]
# **Observation**
# A bit of research on _Multicultural High School_ which has an average SAT score of 887 reveals the following:
# - % of economically disadvantaged students is 92%.
# - The school is made up of mostly students of immigrant hispanic parents
# - The school has no asian, multi-racial or american-indian students.

# %%
#Schools that have less than 10% black students and average SAT scores greater than 1800
print('\033[1m' + "Percentage of African-American students in schools with average SAT scores greater than 1800" + '\033[0m')
combined[(combined['black_per'] < 10) & (combined['avg_total_score'] >1800)][['school_name', 'avg_total_score', 'black_per']]
# Out:
# Percentage of African-American students in schools with average SAT scores greater than 1800
#                              school_name  avg_total_score  black_per
# 33                Stuyvesant High School           2096.0        1.2
# 137         Bronx High School Of Science           1969.0        3.5
# 280          Townsend Harris High School           1910.0        5.9
# 329  Staten Island Technical High School           1953.0        1.1

# %% [markdown]
# **Observation** Research on _Staten Island Technical High School_ that has only 1.1% of black students reveals the following:
# - Less than half the students are economically disadvantaged.
# - The schools hosts a significantly large number of asian and white students
# - The school has representations from almost all communities albeit in significantly small measures

# %% [markdown]
# **Insights**:
# - SAT scores clearly seem biased towards communities besides the asians and the whites. All communities do not seem to be equally resourced to make a fair assessment of average SAT scores.
# - The asian and white could have more resources that enable them to perform better.
# - Economic disadvantage seems to have some role to play in the bad average scores exhibited by the african-american and hispanic communities.

# %% [markdown]
# [Index](Index)

# %% [markdown]
# # 8

# %% [markdown]
# ## Who is my Neighbour?
# **Analysing School Neighbourhoods**

# %% [markdown]
# New York consists of 5 boroughs namely The Bronx, Queens, Brooklyn, Manhattan and Staten Island. Each of these boroughs have a number of distinct neighbourhoods. The neighbourhoods are broken in to smaller divisions that can be identified by zip codes.
#
# Since each school has a zipcode we can group the schools in to neighbourhoods and calculate the average SAT scores for each neighbourhood. This grouping should help to identify the neighbourhoods with the best schools and further analyze the survey respondents.

# %%
#---Do Not Remove--
#Data from 
#Read the neighbourhoods data
neighbour = pd.read_csv('neighbourhood.csv')
neighbour.head(5)
#Allocate the neighbourhood each school belongs to
for i in range(len(combined)):
    zip_code = combined.loc[i,'zip'].astype("float")
    for j in range(len(neighbour)):
        if (zip_code==neighbour.loc[j,'zip1':'zip9']).any():
            combined.loc[i,'neighbourhood']=neighbour.loc[j,'neighbourhood']
combined['neighbourhood'].head()
# Out:
#   borough               neighbourhood   zip1     zip2     zip3     zip4  zip5  \
# 0   Bronx               Central Bronx  10453  10457.0  10460.0      NaN   NaN
# 1   Bronx      Bronx Park and Fordham  10458  10467.0  10468.0      NaN   NaN
# 2   Bronx  High Bridge and Morrisania  10451  10452.0  10456.0      NaN   NaN
# 3   Bronx  Hunts Point and Mott Haven  10454  10455.0  10459.0  10474.0   NaN
# 4   Bronx   Kingsbridge and Riverdale  10463  10471.0      NaN      NaN   NaN
#
#    zip6  zip7  zip8  zip9
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN

# %%
# Out:
# 0    Lower East Side
# 1    Lower East Side
# 2    Lower East Side
# 3    Lower East Side
# 4    Lower East Side
# Name: neighbourhood, dtype: object

# %%
#Calculate the average SAT score for each neighbourhood
neighbourhood_sat = combined.groupby('neighbourhood').mean()['avg_total_score'].sort_values()

# %%
fig,ax = plt.subplots(figsize=(13,12))

#Define color for stem plot
stem_color=['grey' if each!=neighbourhood_sat.max() else 'red' for each in neighbourhood_sat]

#Create stem plot
ax.hlines(y=neighbourhood_sat.index,xmin=0,xmax=neighbourhood_sat.values,colors=stem_color)
ax.scatter(y=neighbourhood_sat.index,x=neighbourhood_sat.values,color=stem_color)

#Customize plot
for each_key in ax.spines.keys():
    ax.spines[each_key].set_visible(False)
ax.tick_params(axis='x',bottom=False,labelbottom=False)
ax.tick_params(axis='y',left=False,labelsize=12)

#Define text format
text_size=lambda x:17 if (x==neighbourhood_sat.max()) else 12
text_color=lambda x:'grey' if x!=neighbourhood_sat.max() else 'black'

#Annotate plot
for i,each_point in zip(range(len(neighbourhood_sat)),neighbourhood_sat):
    ax.text(s=round(each_point,2),x=each_point+20,y=i,
            size=text_size(each_point),
            color=text_color(each_point))
ax.set_title("Average SAT Scores by Neighbourhood",size=22)
plt.show()

# %%
print('\033[1m' + "Schools and their Average SAT scores in South Shore" + '\033[0m')
combined[combined['neighbourhood']=='South Shore'][['school_name','avg_total_score']]
# Out:
# Schools and their Average SAT scores in South Shore
#                              school_name  avg_total_score
# 323                 New Dorp High School           1277.0
# 326              Tottenville High School           1418.0
# 329  Staten Island Technical High School           1953.0

# %% [markdown]
# It is clear from from the above plot that **South Shore** is the neighbourhood. **Staten Island Technical High School** is ranked third in our list of schools with the highest average SAT scores.
#
# We can further analyze the responses of the survey by aggregating it based on neighbourhood.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 9

# %% [markdown]
# ## And Your Response Is..?
# **Analysing the survey responses**

# %% [markdown]
# The four major parameters captured through the surveys were safety, communication, engagement and academic expectations. The participants included teachers, parents and students who rated how their related school performed with respect to the above mentioned parameters. The scores range from 1-10. The assumption is that the best score is a 10 and the worst score is 1.

# %%
combined.iloc[:,54:79].head()
# Out:
#    rr_s  rr_t  rr_p    N_s   N_t    N_p  nr_s  nr_t  nr_p  saf_p_11  com_p_11  \
# 0  89.0    70    39  379.0  26.0  151.0   425    37   389       7.8       7.7
# 1  84.0    95    10  385.0  37.0   46.0   459    39   445       7.9       7.4
# 2   0.0    98    28    NaN  42.0  150.0   566    43   534       8.7       8.2
# 3  90.0   100    21  306.0  29.0   69.0   339    28   325       7.7       7.4
# 4  98.0    68    51  923.0  67.0  736.0   945    98  1446       8.5       7.9
#
#    eng_p_11  aca_p_11  saf_t_11  com_t_11  eng_t_11  aca_t_11  saf_s_11  \
# 0       7.4       7.6       6.3       5.3       6.1       6.5       6.0
# 1       7.2       7.3       6.6       5.8       6.6       7.3       6.0
# 2       8.1       8.4       7.3       8.0       8.0       8.8       NaN
# 3       7.2       7.3       6.4       5.3       6.1       6.8       6.4
# 4       7.9       8.4       7.6       5.6       5.9       7.3       7.3
#
#    com_s_11  eng_s_11  aca_s_11  saf_tot_11  com_tot_11  eng_tot_11  \
# 0       5.6       6.1       6.7         6.7         6.2         6.6
# 1       5.7       6.3       7.0         6.8         6.3         6.7
# 2       NaN       NaN       NaN         7.9         7.9         7.9
# 3       5.9       6.4       7.0         6.9         6.2         6.6
# 4       6.4       7.0       7.7         7.8         6.7         6.9
#
#    aca_tot_11
# 0         7.0
# 1         7.2
# 2         8.4
# 3         7.0
# 4         7.8

# %% [markdown]
# We shall analyze the responses of teacher, parents and students separately and compare whether they are congruous. We shall begin with responses from the parents.

# %%
neighbourhood_response = combined.groupby('neighbourhood').mean()[['avg_total_score','saf_p_11','com_p_11','eng_p_11','aca_p_11']].sort_values('avg_total_score',ascending=False)
neighbourhood_response.style.set_precision(2).background_gradient(cmap='RdYlBu')
# Out:
# <style  type="text/css" >
# #T_ba396_row0_col0,#T_ba396_row5_col1,#T_ba396_row39_col2,#T_ba396_row39_col3,#T_ba396_row39_col4{
#             background-color:  #313695;
#             color:  #f1f1f1;
#         }#T_ba396_row0_col1{
#             background-color:  #e7f6eb;
#             color:  #000000;
#         }#T_ba396_row0_col2{
#             background-color:  #cdeaf3;
#             color:  #000000;
#         }#T_ba396_row0_col3,#T_ba396_row9_col3,#T_ba396_row15_col2,#T_ba396_row24_col4,#T_ba396_row25_col1{
#             background-color:  #8ec2dc;
#             color:  #000000;
#         }#T_ba396_row0_col4,#T_ba396_row8_col3,#T_ba396_row13_col3,#T_ba396_row15_col1,#T_ba396_row17_col1,#T_ba396_row24_col1{
#             background-color:  #cbe9f2;
#             color:  #000000;
#         }#T_ba396_row1_col0{
#             background-color:  #5c90c2;
#             color:  #000000;
#         }#T_ba396_row1_col1,#T_ba396_row14_col1,#T_ba396_row32_col3{
#             background-color:  #fdc173;
#             color:  #000000;
#         }#T_ba396_row1_col2,#T_ba396_row1_col3,#T_ba396_row1_col4,#T_ba396_row18_col1,#T_ba396_row41_col0{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_ba396_row2_col0,#T_ba396_row34_col4{
#             background-color:  #69a0ca;
#             color:  #000000;
#         }#T_ba396_row2_col1,#T_ba396_row2_col2,#T_ba396_row4_col1,#T_ba396_row34_col3{
#             background-color:  #5a8ec1;
#             color:  #000000;
#         }#T_ba396_row2_col3,#T_ba396_row5_col2,#T_ba396_row38_col3{
#             background-color:  #4878b6;
#             color:  #000000;
#         }#T_ba396_row2_col4{
#             background-color:  #6095c4;
#             color:  #000000;
#         }#T_ba396_row3_col0,#T_ba396_row4_col3{
#             background-color:  #d8eff6;
#             color:  #000000;
#         }#T_ba396_row3_col1,#T_ba396_row35_col4{
#             background-color:  #5e93c3;
#             color:  #000000;
#         }#T_ba396_row3_col2,#T_ba396_row23_col1{
#             background-color:  #b0dcea;
#             color:  #000000;
#         }#T_ba396_row3_col3{
#             background-color:  #97c9e0;
#             color:  #000000;
#         }#T_ba396_row3_col4{
#             background-color:  #74add1;
#             color:  #000000;
#         }#T_ba396_row4_col0{
#             background-color:  #e2f4f4;
#             color:  #000000;
#         }#T_ba396_row4_col2{
#             background-color:  #8cc0db;
#             color:  #000000;
#         }#T_ba396_row4_col4{
#             background-color:  #92c5de;
#             color:  #000000;
#         }#T_ba396_row5_col0{
#             background-color:  #ecf8e2;
#             color:  #000000;
#         }#T_ba396_row5_col3{
#             background-color:  #3d5ba7;
#             color:  #f1f1f1;
#         }#T_ba396_row5_col4{
#             background-color:  #3a51a2;
#             color:  #f1f1f1;
#         }#T_ba396_row6_col0{
#             background-color:  #f3fbd4;
#             color:  #000000;
#         }#T_ba396_row6_col1{
#             background-color:  #9fd0e4;
#             color:  #000000;
#         }#T_ba396_row6_col2,#T_ba396_row8_col2,#T_ba396_row21_col2{
#             background-color:  #c1e4ef;
#             color:  #000000;
#         }#T_ba396_row6_col3,#T_ba396_row8_col1,#T_ba396_row15_col3,#T_ba396_row40_col1{
#             background-color:  #b6dfec;
#             color:  #000000;
#         }#T_ba396_row6_col4{
#             background-color:  #bde2ee;
#             color:  #000000;
#         }#T_ba396_row7_col0{
#             background-color:  #f8fccb;
#             color:  #000000;
#         }#T_ba396_row7_col1{
#             background-color:  #daf0f6;
#             color:  #000000;
#         }#T_ba396_row7_col2,#T_ba396_row33_col3{
#             background-color:  #b9e0ed;
#             color:  #000000;
#         }#T_ba396_row7_col3,#T_ba396_row28_col2{
#             background-color:  #f0f9db;
#             color:  #000000;
#         }#T_ba396_row7_col4{
#             background-color:  #d4edf4;
#             color:  #000000;
#         }#T_ba396_row8_col0,#T_ba396_row33_col1{
#             background-color:  #fffcba;
#             color:  #000000;
#         }#T_ba396_row8_col4,#T_ba396_row40_col2{
#             background-color:  #aedbea;
#             color:  #000000;
#         }#T_ba396_row9_col0,#T_ba396_row10_col0{
#             background-color:  #fffbb9;
#             color:  #000000;
#         }#T_ba396_row9_col1{
#             background-color:  #5588be;
#             color:  #000000;
#         }#T_ba396_row9_col2{
#             background-color:  #36479e;
#             color:  #f1f1f1;
#         }#T_ba396_row9_col4,#T_ba396_row24_col2{
#             background-color:  #6da4cc;
#             color:  #000000;
#         }#T_ba396_row10_col1{
#             background-color:  #fdb366;
#             color:  #000000;
#         }#T_ba396_row10_col2,#T_ba396_row15_col0{
#             background-color:  #fee99d;
#             color:  #000000;
#         }#T_ba396_row10_col3{
#             background-color:  #feeda4;
#             color:  #000000;
#         }#T_ba396_row10_col4,#T_ba396_row13_col4,#T_ba396_row16_col2,#T_ba396_row40_col4{
#             background-color:  #f6fbd0;
#             color:  #000000;
#         }#T_ba396_row11_col0{
#             background-color:  #fff8b5;
#             color:  #000000;
#         }#T_ba396_row11_col1{
#             background-color:  #78b0d3;
#             color:  #000000;
#         }#T_ba396_row11_col2{
#             background-color:  #c9e8f2;
#             color:  #000000;
#         }#T_ba396_row11_col3{
#             background-color:  #ebf7e4;
#             color:  #000000;
#         }#T_ba396_row11_col4,#T_ba396_row21_col3{
#             background-color:  #bfe3ef;
#             color:  #000000;
#         }#T_ba396_row12_col0,#T_ba396_row16_col4,#T_ba396_row20_col4{
#             background-color:  #fff6b1;
#             color:  #000000;
#         }#T_ba396_row12_col1{
#             background-color:  #fdc778;
#             color:  #000000;
#         }#T_ba396_row12_col2,#T_ba396_row18_col0{
#             background-color:  #fedc8c;
#             color:  #000000;
#         }#T_ba396_row12_col3{
#             background-color:  #fa9b58;
#             color:  #000000;
#         }#T_ba396_row12_col4,#T_ba396_row20_col1{
#             background-color:  #fec87a;
#             color:  #000000;
#         }#T_ba396_row13_col0{
#             background-color:  #fff5af;
#             color:  #000000;
#         }#T_ba396_row13_col1,#T_ba396_row31_col4{
#             background-color:  #edf8df;
#             color:  #000000;
#         }#T_ba396_row13_col2,#T_ba396_row23_col3,#T_ba396_row24_col3,#T_ba396_row33_col2{
#             background-color:  #9bcce2;
#             color:  #000000;
#         }#T_ba396_row14_col0,#T_ba396_row17_col4,#T_ba396_row32_col2{
#             background-color:  #fff2ac;
#             color:  #000000;
#         }#T_ba396_row14_col2,#T_ba396_row27_col2{
#             background-color:  #fee597;
#             color:  #000000;
#         }#T_ba396_row14_col3,#T_ba396_row27_col3{
#             background-color:  #fca85e;
#             color:  #000000;
#         }#T_ba396_row14_col4,#T_ba396_row16_col0{
#             background-color:  #fee294;
#             color:  #000000;
#         }#T_ba396_row15_col4{
#             background-color:  #87bdd9;
#             color:  #000000;
#         }#T_ba396_row16_col1,#T_ba396_row40_col3{
#             background-color:  #f1fad9;
#             color:  #000000;
#         }#T_ba396_row16_col3{
#             background-color:  #fdb96b;
#             color:  #000000;
#         }#T_ba396_row17_col0{
#             background-color:  #fede8e;
#             color:  #000000;
#         }#T_ba396_row17_col2{
#             background-color:  #fcfec5;
#             color:  #000000;
#         }#T_ba396_row17_col3{
#             background-color:  #fdc576;
#             color:  #000000;
#         }#T_ba396_row18_col2{
#             background-color:  #fff0a8;
#             color:  #000000;
#         }#T_ba396_row18_col3,#T_ba396_row20_col3,#T_ba396_row28_col3{
#             background-color:  #fee192;
#             color:  #000000;
#         }#T_ba396_row18_col4,#T_ba396_row32_col4{
#             background-color:  #fed081;

# %% [markdown]
# **Parents** in the school neighbourhood of:
# - **Gramercy Park and Murray Hill** rated it **safest**. **Port Richmond** was rated **least safe**
# - **Central Bronx** rate its schools as **best** for **communication, engagement and academic expectation**.
# - **Northest Queens** rate the schools **worst** for **communication, engagement and academic expectation**.
#
# Lets analyze whether the response of parents tally with those of the teachers and students.

# %%
neighbourhood_response = combined.groupby('neighbourhood').mean()[['avg_total_score','saf_t_11','com_t_11','eng_t_11','aca_t_11']].sort_values('avg_total_score',ascending=False)
neighbourhood_response.style.set_precision(2).background_gradient(cmap='YlGnBu')
# Out:
# <style  type="text/css" >
# #T_03bb9_row0_col0,#T_03bb9_row8_col1,#T_03bb9_row8_col2,#T_03bb9_row8_col4,#T_03bb9_row14_col3{
#             background-color:  #081d58;
#             color:  #f1f1f1;
#         }#T_03bb9_row0_col1,#T_03bb9_row14_col4{
#             background-color:  #172978;
#             color:  #f1f1f1;
#         }#T_03bb9_row0_col2,#T_03bb9_row6_col2{
#             background-color:  #1c2d81;
#             color:  #f1f1f1;
#         }#T_03bb9_row0_col3{
#             background-color:  #0e2265;
#             color:  #f1f1f1;
#         }#T_03bb9_row0_col4{
#             background-color:  #21308b;
#             color:  #f1f1f1;
#         }#T_03bb9_row1_col0{
#             background-color:  #243c98;
#             color:  #f1f1f1;
#         }#T_03bb9_row1_col1,#T_03bb9_row19_col1{
#             background-color:  #1f80b8;
#             color:  #000000;
#         }#T_03bb9_row1_col2,#T_03bb9_row12_col4{
#             background-color:  #32a6c2;
#             color:  #000000;
#         }#T_03bb9_row1_col3{
#             background-color:  #1e8abd;
#             color:  #000000;
#         }#T_03bb9_row1_col4,#T_03bb9_row3_col0{
#             background-color:  #2094c0;
#             color:  #000000;
#         }#T_03bb9_row2_col0{
#             background-color:  #24459c;
#             color:  #f1f1f1;
#         }#T_03bb9_row2_col1{
#             background-color:  #2075b3;
#             color:  #f1f1f1;
#         }#T_03bb9_row2_col2,#T_03bb9_row4_col3,#T_03bb9_row22_col1{
#             background-color:  #1e83ba;
#             color:  #000000;
#         }#T_03bb9_row2_col3{
#             background-color:  #2076b3;
#             color:  #000000;
#         }#T_03bb9_row2_col4{
#             background-color:  #216bae;
#             color:  #f1f1f1;
#         }#T_03bb9_row3_col1,#T_03bb9_row14_col0,#T_03bb9_row19_col2,#T_03bb9_row21_col1,#T_03bb9_row31_col2,#T_03bb9_row40_col4{
#             background-color:  #55bec1;
#             color:  #000000;
#         }#T_03bb9_row3_col2,#T_03bb9_row9_col3,#T_03bb9_row31_col1{
#             background-color:  #bde5b5;
#             color:  #000000;
#         }#T_03bb9_row3_col3,#T_03bb9_row15_col2{
#             background-color:  #90d4b9;
#             color:  #000000;
#         }#T_03bb9_row3_col4{
#             background-color:  #99d7b8;
#             color:  #000000;
#         }#T_03bb9_row4_col0,#T_03bb9_row18_col4,#T_03bb9_row25_col4,#T_03bb9_row29_col4{
#             background-color:  #269bc1;
#             color:  #000000;
#         }#T_03bb9_row4_col1{
#             background-color:  #1f7ab5;
#             color:  #000000;
#         }#T_03bb9_row4_col2,#T_03bb9_row11_col0,#T_03bb9_row22_col3{
#             background-color:  #4cbac2;
#             color:  #000000;
#         }#T_03bb9_row4_col4{
#             background-color:  #1f93c0;
#             color:  #000000;
#         }#T_03bb9_row5_col0,#T_03bb9_row19_col3{
#             background-color:  #2fa4c2;
#             color:  #000000;
#         }#T_03bb9_row5_col1,#T_03bb9_row6_col4{
#             background-color:  #243392;
#             color:  #f1f1f1;
#         }#T_03bb9_row5_col2,#T_03bb9_row13_col1,#T_03bb9_row24_col2{
#             background-color:  #8cd2ba;
#             color:  #000000;
#         }#T_03bb9_row5_col3,#T_03bb9_row9_col1{
#             background-color:  #2ea3c2;
#             color:  #000000;
#         }#T_03bb9_row5_col4{
#             background-color:  #1d90c0;
#             color:  #000000;
#         }#T_03bb9_row6_col0{
#             background-color:  #36abc3;
#             color:  #000000;
#         }#T_03bb9_row6_col1{
#             background-color:  #1b2c80;
#             color:  #f1f1f1;
#         }#T_03bb9_row6_col3{
#             background-color:  #1f2f87;
#             color:  #f1f1f1;
#         }#T_03bb9_row7_col0{
#             background-color:  #3bb0c3;
#             color:  #000000;
#         }#T_03bb9_row7_col1,#T_03bb9_row10_col4{
#             background-color:  #3db2c4;
#             color:  #000000;
#         }#T_03bb9_row7_col2,#T_03bb9_row31_col4,#T_03bb9_row38_col4{
#             background-color:  #63c3bf;
#             color:  #000000;
#         }#T_03bb9_row7_col3,#T_03bb9_row34_col3{
#             background-color:  #6bc6be;
#             color:  #000000;
#         }#T_03bb9_row7_col4,#T_03bb9_row9_col0,#T_03bb9_row10_col0{
#             background-color:  #48b9c3;
#             color:  #000000;
#         }#T_03bb9_row8_col0,#T_03bb9_row17_col4,#T_03bb9_row38_col1,#T_03bb9_row39_col4{
#             background-color:  #46b8c3;
#             color:  #000000;
#         }#T_03bb9_row8_col3{
#             background-color:  #2070b0;
#             color:  #f1f1f1;
#         }#T_03bb9_row9_col2,#T_03bb9_row22_col0{
#             background-color:  #b9e4b5;
#             color:  #000000;
#         }#T_03bb9_row9_col4,#T_03bb9_row39_col2{
#             background-color:  #7acbbc;
#             color:  #000000;
#         }#T_03bb9_row10_col1{
#             background-color:  #b4e2b6;
#             color:  #000000;
#         }#T_03bb9_row10_col2,#T_03bb9_row16_col1,#T_03bb9_row18_col2,#T_03bb9_row20_col3,#T_03bb9_row29_col3{
#             background-color:  #3cb1c3;
#             color:  #000000;
#         }#T_03bb9_row10_col3,#T_03bb9_row20_col4,#T_03bb9_row30_col3,#T_03bb9_row33_col4{
#             background-color:  #2a9ec1;
#             color:  #000000;
#         }#T_03bb9_row11_col1{
#             background-color:  #2259a6;
#             color:  #f1f1f1;
#         }#T_03bb9_row11_col2,#T_03bb9_row29_col1,#T_03bb9_row36_col4{
#             background-color:  #5dc0c0;
#             color:  #000000;
#         }#T_03bb9_row11_col3,#T_03bb9_row16_col3{
#             background-color:  #34a9c3;
#             color:  #000000;
#         }#T_03bb9_row11_col4{
#             background-color:  #2b9fc2;
#             color:  #000000;
#         }#T_03bb9_row12_col0{
#             background-color:  #50bbc2;
#             color:  #000000;
#         }#T_03bb9_row12_col1,#T_03bb9_row13_col4,#T_03bb9_row21_col3{
#             background-color:  #2296c1;
#             color:  #000000;
#         }#T_03bb9_row12_col2,#T_03bb9_row15_col0,#T_03bb9_row30_col2{
#             background-color:  #65c3bf;
#             color:  #000000;
#         }#T_03bb9_row12_col3{
#             background-color:  #3aaec3;
#             color:  #000000;
#         }#T_03bb9_row13_col0,#T_03bb9_row28_col1,#T_03bb9_row37_col1{
#             background-color:  #52bcc2;
#             color:  #000000;
#         }#T_03bb9_row13_col2{
#             background-color:  #35aac3;
#             color:  #000000;
#         }#T_03bb9_row13_col3,#T_03bb9_row24_col4{
#             background-color:  #4ab9c3;
#             color:  #000000;
#         }#T_03bb9_row14_col1{
#             background-color:  #203089;
#             color:  #f1f1f1;
#         }#T_03bb9_row14_col2{
#             background-color:  #152772;
#             color:  #f1f1f1;
#         }#T_03bb9_row15_col1,#T_03bb9_row24_col3,#T_03bb9_row40_col3{
#             background-color:  #5bc0c0;
#             color:  #000000;
#         }#T_03bb9_row15_col3,#T_03bb9_row16_col2,#T_03bb9_row33_col2{
#             background-color:  #4ebbc2;
#             color:  #000000;
#         }#T_03bb9_row15_col4{
#             background-color:  #40b5c4;
#             color:  #000000;
#         }#T_03bb9_row16_col0{
#             background-color:  #6fc7bd;
#             color:  #000000;
#         }#T_03bb9_row16_col4,#T_03bb9_row17_col1,#T_03bb9_row37_col4{
#             background-color:  #2ca1c2;
#             color:  #000000;
#         }#T_03bb9_row17_col0{
#             background-color:  #75c9bd;
#             color:  #000000;
#         }#T_03bb9_row17_col2,#T_03bb9_row31_col3,#T_03bb9_row41_col3{
#             background-color:  #73c8bd;
#             color:  #000000;
#         }#T_03bb9_row17_col3{
#             background-color:  #31a5c2;
#             color:  #000000;
#         }#T_03bb9_row18_col0{
#             background-color:  #76cabc;
#             color:  #000000;
#         }#T_03bb9_row18_col1,#T_03bb9_row25_col0{
#             background-color:  #cdebb4;
#             color:  #000000;
#         }#T_03bb9_row18_col3,#T_03bb9_row28_col4{
#             background-color:  #42b6c4;
#             color:  #000000;
#         }#T_03bb9_row19_col0{
#             background-color:

# %% [markdown]
# - **Teachers** in the neighbourhoods of **Sunset Park, South Shore, West Central Queens and Borough Park have positively rated** the schools for all parameters with **Sunset Part** being rated **most for safety, communication and academic expectation**.
# - Teachers in **West Central Queens** have rated themselves as best when it comes to **engagement**.
# - Teachers in **Central Harlem** have identified it as the neighbourhood that performs **sub par** with regards to the above identified parameters.

# %%
neighbourhood_response = combined.groupby('neighbourhood').mean()[['avg_total_score','saf_s_11','com_s_11','eng_s_11','aca_s_11']].sort_values('avg_total_score',ascending=False)
neighbourhood_response.style.set_precision(2).background_gradient(cmap='PuBuGn')
# Out:
# <style  type="text/css" >
# #T_79878_row0_col0,#T_79878_row2_col3,#T_79878_row2_col4,#T_79878_row5_col1,#T_79878_row5_col2{
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }#T_79878_row0_col1{
#             background-color:  #01746c;
#             color:  #f1f1f1;
#         }#T_79878_row0_col2{
#             background-color:  #027978;
#             color:  #f1f1f1;
#         }#T_79878_row0_col3{
#             background-color:  #014737;
#             color:  #f1f1f1;
#         }#T_79878_row0_col4{
#             background-color:  #016956;
#             color:  #f1f1f1;
#         }#T_79878_row1_col0{
#             background-color:  #017062;
#             color:  #f1f1f1;
#         }#T_79878_row1_col1,#T_79878_row3_col3,#T_79878_row28_col3{
#             background-color:  #1d89a6;
#             color:  #000000;
#         }#T_79878_row1_col2{
#             background-color:  #acc0dd;
#             color:  #000000;
#         }#T_79878_row1_col3,#T_79878_row25_col3{
#             background-color:  #4698c5;
#             color:  #000000;
#         }#T_79878_row1_col4,#T_79878_row13_col4,#T_79878_row14_col4,#T_79878_row17_col4,#T_79878_row26_col1,#T_79878_row35_col4{
#             background-color:  #549fc9;
#             color:  #000000;
#         }#T_79878_row2_col0,#T_79878_row2_col2{
#             background-color:  #01756d;
#             color:  #f1f1f1;
#         }#T_79878_row2_col1{
#             background-color:  #014b3a;
#             color:  #f1f1f1;
#         }#T_79878_row3_col0{
#             background-color:  #3a92c1;
#             color:  #000000;
#         }#T_79878_row3_col1{
#             background-color:  #0e8496;
#             color:  #000000;
#         }#T_79878_row3_col2,#T_79878_row22_col2,#T_79878_row39_col3{
#             background-color:  #2a8cb3;
#             color:  #000000;
#         }#T_79878_row3_col4,#T_79878_row6_col3,#T_79878_row8_col2,#T_79878_row8_col3,#T_79878_row21_col2,#T_79878_row34_col1{
#             background-color:  #11859a;
#             color:  #000000;
#         }#T_79878_row4_col0,#T_79878_row16_col1{
#             background-color:  #4397c4;
#             color:  #000000;
#         }#T_79878_row4_col1{
#             background-color:  #017267;
#             color:  #f1f1f1;
#         }#T_79878_row4_col2,#T_79878_row38_col2{
#             background-color:  #027b7b;
#             color:  #f1f1f1;
#         }#T_79878_row4_col3,#T_79878_row21_col3,#T_79878_row34_col2{
#             background-color:  #06828e;
#             color:  #f1f1f1;
#         }#T_79878_row4_col4{
#             background-color:  #098391;
#             color:  #f1f1f1;
#         }#T_79878_row5_col0{
#             background-color:  #4f9dc8;
#             color:  #000000;
#         }#T_79878_row5_col3,#T_79878_row9_col4{
#             background-color:  #016f5f;
#             color:  #f1f1f1;
#         }#T_79878_row5_col4{
#             background-color:  #016350;
#             color:  #f1f1f1;
#         }#T_79878_row6_col0{
#             background-color:  #58a2cb;
#             color:  #000000;
#         }#T_79878_row6_col1,#T_79878_row9_col3{
#             background-color:  #027772;
#             color:  #f1f1f1;
#         }#T_79878_row6_col2,#T_79878_row25_col2{
#             background-color:  #519ec8;
#             color:  #000000;
#         }#T_79878_row6_col4,#T_79878_row25_col1{
#             background-color:  #208aa9;
#             color:  #000000;
#         }#T_79878_row7_col0{
#             background-color:  #5fa5cc;
#             color:  #000000;
#         }#T_79878_row7_col1,#T_79878_row7_col3,#T_79878_row12_col3{
#             background-color:  #68a9cf;
#             color:  #000000;
#         }#T_79878_row7_col2,#T_79878_row8_col0,#T_79878_row20_col1,#T_79878_row23_col3{
#             background-color:  #6cabd0;
#             color:  #000000;
#         }#T_79878_row7_col4{
#             background-color:  #4b9ac6;
#             color:  #000000;
#         }#T_79878_row8_col1,#T_79878_row36_col1{
#             background-color:  #027e83;
#             color:  #f1f1f1;
#         }#T_79878_row8_col4,#T_79878_row21_col4,#T_79878_row34_col4,#T_79878_row36_col3,#T_79878_row38_col4{
#             background-color:  #027c7e;
#             color:  #f1f1f1;
#         }#T_79878_row9_col0,#T_79878_row10_col0,#T_79878_row16_col2,#T_79878_row23_col1,#T_79878_row31_col2,#T_79878_row40_col3{
#             background-color:  #6eabd0;
#             color:  #000000;
#         }#T_79878_row9_col1{
#             background-color:  #017369;
#             color:  #f1f1f1;
#         }#T_79878_row9_col2{
#             background-color:  #027d80;
#             color:  #f1f1f1;
#         }#T_79878_row10_col1,#T_79878_row31_col1{
#             background-color:  #84b2d4;
#             color:  #000000;
#         }#T_79878_row10_col2,#T_79878_row24_col3,#T_79878_row41_col2,#T_79878_row41_col3{
#             background-color:  #6aaad0;
#             color:  #000000;
#         }#T_79878_row10_col3{
#             background-color:  #2b8db5;
#             color:  #000000;
#         }#T_79878_row10_col4,#T_79878_row12_col0,#T_79878_row16_col4,#T_79878_row19_col4,#T_79878_row29_col2,#T_79878_row40_col4{
#             background-color:  #76aed2;
#             color:  #000000;
#         }#T_79878_row11_col0{
#             background-color:  #72acd1;
#             color:  #000000;
#         }#T_79878_row11_col1{
#             background-color:  #027875;
#             color:  #f1f1f1;
#         }#T_79878_row11_col2,#T_79878_row13_col2,#T_79878_row28_col1{
#             background-color:  #328fbc;
#             color:  #000000;
#         }#T_79878_row11_col3,#T_79878_row30_col3,#T_79878_row36_col4{
#             background-color:  #1e89a7;
#             color:  #000000;
#         }#T_79878_row11_col4{
#             background-color:  #1b88a4;
#             color:  #000000;
#         }#T_79878_row12_col1,#T_79878_row24_col4{
#             background-color:  #65a8ce;
#             color:  #000000;
#         }#T_79878_row12_col2,#T_79878_row13_col0{
#             background-color:  #78aed2;
#             color:  #000000;
#         }#T_79878_row12_col4,#T_79878_row15_col0{
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }#T_79878_row13_col1,#T_79878_row19_col2,#T_79878_row26_col4{
#             background-color:  #3590bf;
#             color:  #000000;
#         }#T_79878_row13_col3,#T_79878_row22_col3{
#             background-color:  #1988a2;
#             color:  #000000;
#         }#T_79878_row14_col0,#T_79878_row33_col2{
#             background-color:  #7cb0d3;
#             color:  #000000;
#         }#T_79878_row14_col1{
#             background-color:  #499ac6;
#             color:  #000000;
#         }#T_79878_row14_col2{
#             background-color:  #9fbbda;
#             color:  #000000;
#         }#T_79878_row14_col3,#T_79878_row26_col2{
#             background-color:  #529ec9;
#             color:  #000000;
#         }#T_79878_row15_col1{
#             background-color:  #268bb0;
#             color:  #000000;
#         }#T_79878_row15_col2,#T_79878_row15_col3{
#             background-color:  #218aab;
#             color:  #000000;
#         }#T_79878_row15_col4,#T_79878_row25_col4,#T_79878_row29_col4{
#             background-color:  #258bae;
#             color:  #000000;
#         }#T_79878_row16_col0,#T_79878_row27_col2{
#             background-color:  #95b8d8;
#             color:  #000000;
#         }#T_79878_row16_col3{
#             background-color:  #91b6d7;
#             color:  #000000;
#         }#T_79878_row17_col0{
#             background-color:  #9bbad9;
#             color:  #000000;
#         }#T_79878_row17_col1{
#             background-color:  #14869d;
#             color:  #000000;
#         }#T_79878_row17_col2,#T_79878_row31_col3,#T_79878_row37_col3,#T_79878_row39_col1{
#             background-color:  #3d93c2;
#             color:  #000000;
#         }#T_79878_row17_col3{
#             background-color:  #55a0ca;
#             color:  #000000;
#         }#T_79878_row18_col0{
#             background-color:  #9dbad9;
#             color:  #000000;
#         }#T_79878_row18_col1,#T_79878_row18_col2,#T_79878_row18_col3,#T_79878_row18_col4,#T_79878_row41_col0{
#             background-color:  #fff7fb;
#             color:  #000000;

# %% [markdown]
# - Schools in **Gramercy Park and Murray Hill** seem to be the **most rated** by their students in matters of **safety and communication**.
# - Students in **Central Queens** are of the opinion that they **outperform** all other neighbourhoods when it comes to **safety, engagement and academic expectation**.
# - Students in the **Port Richmond** neighbourhood believe the schools in the area **under perform** on all counts of the identified parameters.

# %% [markdown]
# Since the dataset also provides a consolidated score based on the responses of teacher, parents and students. We could analyze which neighbourhoods have been most rated for the identified parameters.

# %%
neighbourhood_response = combined.groupby('neighbourhood').mean()[['avg_total_score','saf_tot_11','com_tot_11','eng_tot_11','aca_tot_11']].sort_values('avg_total_score',ascending=False)
neighbourhood_response.style.set_precision(2).background_gradient(cmap='PuBuGn')
# Out:
# <style  type="text/css" >
# #T_146a4_row0_col0,#T_146a4_row0_col3,#T_146a4_row5_col1,#T_146a4_row8_col2,#T_146a4_row8_col4{
#             background-color:  #014636;
#             color:  #f1f1f1;
#         }#T_146a4_row0_col1{
#             background-color:  #027b7d;
#             color:  #f1f1f1;
#         }#T_146a4_row0_col2{
#             background-color:  #015745;
#             color:  #f1f1f1;
#         }#T_146a4_row0_col4{
#             background-color:  #015948;
#             color:  #f1f1f1;
#         }#T_146a4_row1_col0{
#             background-color:  #017062;
#             color:  #f1f1f1;
#         }#T_146a4_row1_col1,#T_146a4_row21_col1,#T_146a4_row28_col1{
#             background-color:  #57a1ca;
#             color:  #000000;
#         }#T_146a4_row1_col2{
#             background-color:  #dcd8ea;
#             color:  #000000;
#         }#T_146a4_row1_col3,#T_146a4_row19_col3{
#             background-color:  #80b1d4;
#             color:  #000000;
#         }#T_146a4_row1_col4,#T_146a4_row41_col3,#T_146a4_row41_col4{
#             background-color:  #a1bcda;
#             color:  #000000;
#         }#T_146a4_row2_col0,#T_146a4_row6_col1{
#             background-color:  #01756d;
#             color:  #f1f1f1;
#         }#T_146a4_row2_col1,#T_146a4_row2_col2{
#             background-color:  #016a57;
#             color:  #f1f1f1;
#         }#T_146a4_row2_col3{
#             background-color:  #016b58;
#             color:  #f1f1f1;
#         }#T_146a4_row2_col4{
#             background-color:  #015140;
#             color:  #f1f1f1;
#         }#T_146a4_row3_col0,#T_146a4_row15_col4{
#             background-color:  #3a92c1;
#             color:  #000000;
#         }#T_146a4_row3_col1,#T_146a4_row14_col2{
#             background-color:  #268bb0;
#             color:  #000000;
#         }#T_146a4_row3_col2,#T_146a4_row7_col2,#T_146a4_row35_col2{
#             background-color:  #82b1d4;
#             color:  #000000;
#         }#T_146a4_row3_col3,#T_146a4_row26_col2,#T_146a4_row28_col2{
#             background-color:  #70acd1;
#             color:  #000000;
#         }#T_146a4_row3_col4{
#             background-color:  #4c9bc7;
#             color:  #000000;
#         }#T_146a4_row4_col0,#T_146a4_row13_col4,#T_146a4_row25_col2{
#             background-color:  #4397c4;
#             color:  #000000;
#         }#T_146a4_row4_col1,#T_146a4_row11_col1{
#             background-color:  #027773;
#             color:  #f1f1f1;
#         }#T_146a4_row4_col2,#T_146a4_row38_col4{
#             background-color:  #208aa9;
#             color:  #000000;
#         }#T_146a4_row4_col3,#T_146a4_row4_col4,#T_146a4_row29_col4{
#             background-color:  #0f8598;
#             color:  #000000;
#         }#T_146a4_row5_col0,#T_146a4_row25_col3{
#             background-color:  #4f9dc8;
#             color:  #000000;
#         }#T_146a4_row5_col2,#T_146a4_row5_col3{
#             background-color:  #02818a;
#             color:  #f1f1f1;
#         }#T_146a4_row5_col4{
#             background-color:  #016d5b;
#             color:  #f1f1f1;
#         }#T_146a4_row6_col0{
#             background-color:  #58a2cb;
#             color:  #000000;
#         }#T_146a4_row6_col2{
#             background-color:  #016e5e;
#             color:  #f1f1f1;
#         }#T_146a4_row6_col3{
#             background-color:  #017267;
#             color:  #f1f1f1;
#         }#T_146a4_row6_col4,#T_146a4_row8_col1{
#             background-color:  #017165;
#             color:  #f1f1f1;
#         }#T_146a4_row7_col0,#T_146a4_row13_col1,#T_146a4_row31_col2{
#             background-color:  #5fa5cc;
#             color:  #000000;
#         }#T_146a4_row7_col1,#T_146a4_row24_col1{
#             background-color:  #74add1;
#             color:  #000000;
#         }#T_146a4_row7_col3,#T_146a4_row18_col0{
#             background-color:  #9dbad9;
#             color:  #000000;
#         }#T_146a4_row7_col4,#T_146a4_row33_col3,#T_146a4_row35_col4{
#             background-color:  #5da4cc;
#             color:  #000000;
#         }#T_146a4_row8_col0{
#             background-color:  #6cabd0;
#             color:  #000000;
#         }#T_146a4_row8_col3,#T_146a4_row14_col3{
#             background-color:  #098391;
#             color:  #f1f1f1;
#         }#T_146a4_row9_col0,#T_146a4_row10_col0{
#             background-color:  #6eabd0;
#             color:  #000000;
#         }#T_146a4_row9_col1{
#             background-color:  #028189;
#             color:  #f1f1f1;
#         }#T_146a4_row9_col2,#T_146a4_row29_col2,#T_146a4_row30_col1,#T_146a4_row30_col2,#T_146a4_row34_col2,#T_146a4_row39_col2{
#             background-color:  #3891c1;
#             color:  #000000;
#         }#T_146a4_row9_col3,#T_146a4_row10_col4,#T_146a4_row28_col3,#T_146a4_row29_col3,#T_146a4_row31_col4{
#             background-color:  #6aaad0;
#             color:  #000000;
#         }#T_146a4_row9_col4,#T_146a4_row11_col4{
#             background-color:  #238bac;
#             color:  #000000;
#         }#T_146a4_row10_col1,#T_146a4_row20_col0,#T_146a4_row27_col3{
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }#T_146a4_row10_col2,#T_146a4_row13_col0,#T_146a4_row17_col3{
#             background-color:  #78aed2;
#             color:  #000000;
#         }#T_146a4_row10_col3,#T_146a4_row24_col4{
#             background-color:  #55a0ca;
#             color:  #000000;
#         }#T_146a4_row11_col0,#T_146a4_row20_col4,#T_146a4_row31_col3{
#             background-color:  #72acd1;
#             color:  #000000;
#         }#T_146a4_row11_col2,#T_146a4_row15_col2{
#             background-color:  #5ba3cb;
#             color:  #000000;
#         }#T_146a4_row11_col3,#T_146a4_row13_col3,#T_146a4_row34_col3{
#             background-color:  #4b9ac6;
#             color:  #000000;
#         }#T_146a4_row12_col0,#T_146a4_row12_col1,#T_146a4_row26_col3{
#             background-color:  #76aed2;
#             color:  #000000;
#         }#T_146a4_row12_col2{
#             background-color:  #b3c3de;
#             color:  #000000;
#         }#T_146a4_row12_col3,#T_146a4_row20_col3,#T_146a4_row23_col3{
#             background-color:  #93b7d7;
#             color:  #000000;
#         }#T_146a4_row12_col4{
#             background-color:  #91b6d7;
#             color:  #000000;
#         }#T_146a4_row13_col2,#T_146a4_row21_col3{
#             background-color:  #328fbc;
#             color:  #000000;
#         }#T_146a4_row14_col0,#T_146a4_row26_col4{
#             background-color:  #7cb0d3;
#             color:  #000000;
#         }#T_146a4_row14_col1{
#             background-color:  #3e94c3;
#             color:  #000000;
#         }#T_146a4_row14_col4,#T_146a4_row22_col1{
#             background-color:  #027f84;
#             color:  #f1f1f1;
#         }#T_146a4_row15_col0{
#             background-color:  #8cb5d6;
#             color:  #000000;
#         }#T_146a4_row15_col1{
#             background-color:  #4698c5;
#             color:  #000000;
#         }#T_146a4_row15_col3{
#             background-color:  #529ec9;
#             color:  #000000;
#         }#T_146a4_row16_col0{
#             background-color:  #95b8d8;
#             color:  #000000;
#         }#T_146a4_row16_col1,#T_146a4_row23_col4,#T_146a4_row33_col2{
#             background-color:  #65a8ce;
#             color:  #000000;
#         }#T_146a4_row16_col2,#T_146a4_row17_col0{
#             background-color:  #9bbad9;
#             color:  #000000;
#         }#T_146a4_row16_col3{
#             background-color:  #a5bddb;
#             color:  #000000;
#         }#T_146a4_row16_col4,#T_146a4_row26_col1{
#             background-color:  #68a9cf;
#             color:  #000000;
#         }#T_146a4_row17_col1,#T_146a4_row22_col2{
#             background-color:  #308eba;
#             color:  #000000;
#         }#T_146a4_row17_col2,#T_146a4_row20_col2,#T_146a4_row35_col1{
#             background-color:  #8ab4d6;
#             color:  #000000;
#         }#T_146a4_row17_col4,#T_146a4_row24_col3{
#             background-color:  #7aafd3;
#             color:  #000000;
#         }#T_146a4_row18_col1,#T_146a4_row32_col2,#T_146a4_row32_col3,#T_146a4_row32_col4,#T_146a4_row41_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_146a4_row18_col2,#T_146a4_r

# %% [markdown]
# - **Gramercy Park & Murray Hill** was identified as the **safest** neighbourhood.
# - **Sunset Park** was **rated most** for **communication and academic expectation**.
# - **Engagement** has its **highest score** in the **South Shore** neighbourhood.
# - The total scores for **Central Harlem** almost mimicked the scores assigned by the teachers in Central Harlem. Overall Central Harlem has the **least score** for **communication, engagement and academic expectations**.
# - **Port Richmond** has the **least** total score for **safety**.

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 10

# %% [markdown]
# ## Least of the Best
# **Identifying the least expensive neighbourhood with the best schools**

# %% [markdown]
# We have identified the best schools by their SAT scores. We have also identified some of the neighbourhoods with these good schools. However, the best schools usually tend to be in the most expensive areas.
#
# We could analyse the real estate prices for each neighbourhood and identify the best schools in the least expensive areas. We shall begin by analysing the [real estate](https://www.kaggle.com/new-york-city/nyc-property-sales) data associated to New York neighbourhoods.

# %%
ny_real_estate=pd.read_csv('nyc-rolling-sales.csv')
columns=['Unnamed: 0', 'BOROUGH','BUILDING CLASS CATEGORY',
         'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 
         'EASE-MENT','BUILDING CLASS AT PRESENT', 'ADDRESS', 
         'APARTMENT NUMBER','RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 
         'TOTAL UNITS','LAND SQUARE FEET', 'GROSS SQUARE FEET', 
         'YEAR BUILT','TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
         'SALE DATE']
ny_real_estate.drop(columns=columns,inplace=True)
ny_real_estate.columns = ny_real_estate.columns.str.lower()
ny_real_estate['neighborhood']=ny_real_estate['neighborhood'].str.title()
#-----
dict_zip={}
for i in range(ny_real_estate.shape[0]):
    neighborhood=ny_real_estate.loc[i,'neighborhood']
    zip_code = ny_real_estate.loc[i,'zip code']
    if neighborhood in dict_zip:
        if (zip_code not in dict_zip[neighborhood]) & zip_code!=0:
            dict_zip[neighborhood].append(zip_code)
    else:
        dict_zip[neighborhood]=[]
        dict_zip[neighborhood].append(zip_code)
#------
def process_zip(zipy):
    for key,value in dict_zip.items():
        if zipy in value:
            return key
#process_zip = lambda zipy:dict_zip[each_record].key() if (zipy in dict_zip[each_record]) else None for each record in dict_zip
comb["loc2"]=comb["zip"].apply(process_zip)
#------
ny_real_estate.columns
# Out:
# Index(['Unnamed: 0', 'BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')

# %%
columns=['Unnamed: 0', 'BOROUGH','BUILDING CLASS CATEGORY',
         'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 
         'EASE-MENT','BUILDING CLASS AT PRESENT', 'ADDRESS', 
         'APARTMENT NUMBER','RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 
         'TOTAL UNITS','LAND SQUARE FEET', 'GROSS SQUARE FEET', 
         'YEAR BUILT','TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
         'SALE DATE']
ny_real_estate.drop(columns=columns,inplace=True)
ny_real_estate
# Out:
#         NEIGHBORHOOD  ZIP CODE SALE PRICE
# 0      ALPHABET CITY     10009    6625000
# 1      ALPHABET CITY     10009        -
# 2      ALPHABET CITY     10009        -
# 3      ALPHABET CITY     10009    3936272
# 4      ALPHABET CITY     10009    8000000
# ...              ...       ...        ...
# 84543        WOODROW     10309     450000
# 84544        WOODROW     10309     550000
# 84545        WOODROW     10309     460000
# 84546        WOODROW     10309   11693337
# 84547        WOODROW     10309      69300
#
# [84548 rows x 3 columns]

# %%
ny_real_estate.columns = ny_real_estate.columns.str.lower()
ny_real_estate['neighborhood']=ny_real_estate['neighborhood'].str.title()

# %%
for i,each_record in zip(range(combined.shape[0]),combined['dbn']):
    print(each_record)
# Out:
# 01M292
# 01M448
# 01M450
# 01M509
# 01M539
# 01M696
# 02M047
# 02M288
# 02M294
# 02M296
# 02M298
# 02M300
# 02M303
# 02M305
# 02M308
# 02M316
# 02M374
# 02M376
# 02M400
# 02M407
# 02M408
# 02M411
# 02M412
# 02M413
# 02M414
# 02M416
# 02M418
# 02M419
# 02M420
# 02M425
# 02M439
# 02M449
# 02M459
# 02M475
# 02M489
# 02M500
# 02M519
# 02M520
# 02M529
# 02M531
# 02M542
# 02M543
# 02M545
# 02M551
# 02M580
# 02M600
# 02M605
# 02M615
# 02M630
# 02M655
# 03M299
# 03M307
# 03M415
# 03M479
# 03M485
# 03M492
# 03M494
# 03M541
# 03M860
# 04M409
# 04M435
# 04M495
# 04M555
# 04M610
# 04M680
# 05M304
# 05M367
# 05M369
# 05M499
# 05M670
# 05M692
# 06M293
# 06M346
# 06M348
# 06M462
# 06M463
# 06M467
# 06M468
# 06M540
# 06M552
# 07X221
# 07X334
# 07X427
# 07X473
# 07X495
# 07X500
# 07X520
# 07X527
# 07X547
# 07X548
# 07X551
# 07X600
# 07X670
# 08X282
# 08X293
# 08X305
# 08X312
# 08X332
# 08X405
# 08X519
# 08X530
# 09X227
# 09X231
# 09X241
# 09X250
# 09X252
# 09X260
# 09X263
# 09X276
# 09X297
# 09X329
# 09X365
# 09X403
# 09X404
# 09X412
# 09X413
# 09X505
# 09X517
# 09X525
# 09X543
# 10X141
# 10X213
# 10X225
# 10X237
# 10X243
# 10X268
# 10X284
# 10X342
# 10X368
# 10X374
# 10X433
# 10X434
# 10X437
# 10X438
# 10X439
# 10X440
# 10X442
# 10X445
# 10X477
# 10X546
# 10X549
# 10X696
# 11X249
# 11X253
# 11X265
# 11X270
# 11X275
# 11X288
# 11X290
# 11X299
# 11X418
# 11X455
# 11X513
# 11X514
# 11X542
# 11X544
# 11X545
# 12X248
# 12X251
# 12X267
# 12X271
# 12X278
# 12X388
# 12X550
# 12X682
# 12X684
# 12X692
# 13K265
# 13K350
# 13K412
# 13K419
# 13K430
# 13K439
# 13K483
# 13K499
# 13K595
# 13K605
# 13K670
# 13K674
# 14K071
# 14K449
# 14K454
# 14K474
# 14K477
# 14K478
# 14K488
# 14K558
# 14K561
# 14K586
# 14K610
# 14K632
# 14K685
# 15K429
# 15K448
# 15K462
# 15K463
# 15K464
# 15K497
# 15K519
# 15K656
# 16K393
# 16K455
# 16K498
# 17K382
# 17K408
# 17K524
# 17K528
# 17K531
# 17K533
# 17K537
# 17K539
# 17K543
# 17K546
# 17K547
# 17K548
# 17K590
# 17K600
# 18K563
# 18K566
# 18K567
# 18K569
# 18K576
# 18K589
# 18K617
# 18K629
# 18K633
# 18K637
# 18K642
# 19K409
# 19K502
# 19K504
# 19K507
# 19K510
# 19K583
# 19K615
# 19K618
# 19K639
# 19K659
# 19K660
# 19K683
# 20K445
# 20K485
# 20K490
# 20K505
# 21K337
# 21K344
# 21K348
# 21K410
# 21K525
# 21K540
# 21K559
# 21K572
# 21K620
# 21K690
# 22K405
# 22K425
# 22K535
# 22K555
# 23K493
# 23K514
# 23K697
# 24Q264
# 24Q267
# 24Q293
# 24Q296
# 24Q299
# 24Q455
# 24Q485
# 24Q520
# 24Q530
# 24Q550
# 24Q560
# 24Q600
# 24Q610
# 25Q252
# 25Q263
# 25Q281
# 25Q285
# 25Q425
# 25Q460
# 25Q525
# 25Q670
# 26Q415
# 26Q430
# 26Q435
# 26Q495
# 26Q566
# 27Q260
# 27Q262
# 27Q302
# 27Q308
# 27Q309
# 27Q323
# 27Q400
# 27Q475
# 27Q480
# 27Q650
# 28Q310
# 28Q440
# 28Q505
# 28Q620
# 28Q680
# 28Q687
# 28Q690
# 28Q896
# 29Q248
# 29Q259
# 29Q265
# 29Q272
# 29Q283
# 29Q492
# 29Q498
# 30Q301
# 30Q445
# 30Q450
# 30Q501
# 30Q502
# 30Q555
# 30Q575
# 30Q580
# 31R047
# 31R064
# 31R080
# 31R440
# 31R445
# 31R450
# 31R455
# 31R460
# 31R600
# 31R605
# 32K403
# 32K545
# 32K549
# 32K552
# 32K554
# 32K556

# %%
dict_zip={}
for i in range(ny_real_estate.shape[0]):
    neighborhood=ny_real_estate.loc[i,'neighborhood']
    zip_code = ny_real_estate.loc[i,'zip code']
    if neighborhood in dict_zip:
        if (zip_code not in dict_zip[neighborhood]) & zip_code!=0:
            dict_zip[neighborhood].append(zip_code)
    else:
        dict_zip[neighborhood]=[]
        dict_zip[neighborhood].append(zip_code)
dict_zip
# Out:
# {'Alphabet City': [10009],
#  'Chelsea': [10011, 10001, 10013],
#  'Chinatown': [10013],
#  'Civic Center': [10013, 10007],
#  'Clinton': [10036, 10019],
#  'East Village': [10009, 10003, 10013],
#  'Fashion': [10018, 10001],
#  'Financial': [10005],
#  'Flatiron': [10003, 10011, 10001],
#  'Gramercy': [10003],
#  'Greenwich Village-Central': [10012, 10011, 10003],
#  'Greenwich Village-West': [10014, 10011, 10019],
#  'Harlem-Central': [10026, 10031, 10027, 10035, 10037, 10029, 10039],
#  'Harlem-East': [10029, 10035],
#  'Harlem-Upper': [10031],
#  'Harlem-West': [10031, 10027],
#  'Inwood': [10463],
#  'Javits Center': [10018, 10001],
#  'Kips Bay': [10003],
#  'Little Italy': [10013],
#  'Lower East Side': [10002],
#  'Manhattan Valley': [10026, 10025],
#  'Midtown Cbd': [10022, 10017, 10167],
#  'Midtown East': [10017],
#  'Midtown West': [10019, 10023, 10105],
#  'Morningside Heights': [10027],
#  'Murray Hill': [10016, 10033],
#  'Roosevelt Island': [10044],
#  'Soho': [10013],
#  'Southbridge': [10038],
#  'Tribeca': [10013, 10007, 10281],
#  'Upper East Side (59-79)': [10065, 10021, 10075],
#  'Upper East Side (79-96)': [10075],
#  'Upper East Side (96-110)': [10029],
#  'Upper West Side (59-79)': [10023, 10019, 10069],
#  'Upper West Side (79-96)': [10024, 10025],
#  'Upper West Side (96-116)': [10025],
#  'Washington Heights Lower': [10032, 10033],
#  'Washington Heights Upper': [10033],
#  'Bathgate': [10457, 10451],
#  'Baychester': [10469, 10475],
#  'Bedford Park/Norwood': [10458, 10467],
#  'Belmont': [10458, 10457],
#  'Bronx Park': [10467],
#  'Bronxdale': [10467, 10469],
#  'Castle Hill/Unionport': [10473],
#  'City Island': [10464],
#  'City Island-Pelham Strip': [10803],
#  'Co-Op City': [10475],
#  'Country Club': [10465],
#  'Crotona Park': [10460, 10457, 10459],
#  'East River': [10465],
#  'East Tremont': [10457],
#  'Fieldston': [10471],
#  'Fordham': [10458, 10457, 10453],
#  'Highbridge/Morris Heights': [10452, 10453, 10451],
#  'Hunts Point': [10474, 10455],
#  'Kingsbridge Hts/Univ Hts': [10468, 10453, 10463],
#  'Kingsbridge/Jerome Park': [10463, 10471],
#  'Melrose/Concourse': [10451, 10455],
#  'Morris Park/Van Nest': [10462, 10461],
#  'Morrisania/Longwood': [10456, 10455, 10459, 10451],
#  'Mott Haven/Port Morris': [10454, 10455, 10451],
#  'Mount Hope/Mount Eden': [10457, 10453],
#  'Parkchester': [10460],
#  'Pelham Bay': [0],
#  'Pelham Gardens': [10469],
#  'Pelham Parkway North': [10469, 10467],
#  'Pelham Parkway South': [10461],
#  'Riverdale': [10463, 10471],
#  'Schuylerville/Pelham Bay': [10461, 10465],
#  'Soundview': [10473],
#  'Throgs Neck': [10465],
#  'Van Cortlandt Park': [10471],
#  'Wakefield': [10466],
#  'Westchester': [10462, 10461],
#  'Williamsbridge': [10467, 10469],
#  'Woodlawn': [10470],
#  'Bath Beach': [11228],
#  'Bay Ridge': [11220, 11209, 11219],
#  'Bedford Stuyvesant': [11221, 11233, 11213, 11205],
#  'Bensonhurst': [11204, 11219],
#  'Bergen Beach': [11234],
#  'Boerum Hill': [11217, 11201],
#  'Borough Park': [11218, 11219],
#  'Brighton Beach': [11235],
#  'Brooklyn Heights': [11201],
#  'Brownsville': [11212, 11233],
#  'Bush Terminal': [11232],
#  'Bushwick': [11206, 11221, 11237, 11207],
#  'Canarsie': [11236, 11239],
#  'Carroll Gardens': [11231, 11201],
#  'Clinton Hill': [11205, 11249],
#  'Cobble Hill': [11201, 11231],
#  'Cobble Hill-West': [11231, 11201],
#  'Coney Island': [11224],
#  'Crown Heights': [11238, 11213, 11225, 11233],
#  'Cypress Hills': [11207],
#  'Downtown-Fulton Ferry': [11201],
#  'Downtown-Fulton Mall': [11201, 11217],
#  'Downtown-Metrotech': [11201],
#  'Dyker Heights': [11219],
#  'East New York': [11207],
#  'Flatbush-Central': [11226],
#  'Flatbush-East': [11203],
#  'Flatbush-Lefferts Garden': [11225],
#  'Flatbush-North': [11225, 11213, 11203],
#  'Flatlands': [11234],
#  'Fort Greene': [11205, 11217, 11201],
#  'Gerritsen Beach': [11229],
#  'Gowanus': [11217, 11231, 11215],
#  'Gravesend': [11204, 11229, 11223],
#  'Greenpoint': [11222, 11211],
#  'Jamaica Bay': [11234, 11693, 11691],
#  'Kensington': [11218],
#  'Madison': [11229, 11223],
#  'Manhattan Beach': [11235],
#  'Marine Park': [11229],
#  'Midwood': [11230, 11229, 11223],
#  'Mill Basin': [11234],
#  'Navy Yard': [11205],
#  'Ocean Hill': [11233, 11207, 11221],
#  'Ocean Parkway-North': [11218, 11223, 11201],
#  'Ocean Parkway-South': [11223, 11235],
#  'Old Mill Basin': [11234],
#  'Park Slope': [11217, 11215],
#  'Park Slope South': [11215],
#  'Prospect Heights': [11238, 11217],
#  'Red Hook': [11231],
#  'Seagate': [11224],
#  'Sheepshead Bay': [11229, 11235, 11223],
#  'Spring Creek': [11239],
#  'Sunset Park': [11215, 11213],
#  'Williamsburg-Central': [11211, 11249, 11205],
#  'Williamsburg-East': [11206, 11211, 11237, 11221],
#  'Williamsburg-North': [11249, 11211],
#  'Williamsburg-South': [11211, 11249],
#  'Windsor Terrace': [11218, 11215],
#  'Wyckoff Heights': [11237],
#  'Airport La Guardia': [11370],
#  'Arverne': [11691],
#  'Astoria': [11102, 11103, 11377, 11105, 11101],
#  'Bayside': [11361, 11357, 11693],
#  'Beechhurst': [11357],
#  'Belle Harbor': [11694],
#  'Bellerose': [11426, 11001],
#  'Briarwood': [11435],
#  'Broad Channel': [11693],
#  'Cambria Heights': [11411, 11435, 11691],
#  'College Point': [11356, 11357],
#  'Corona': [11368, 11373],
#  'Douglaston': [11363],
#  'East Elmhurst': [11369],
#  'Elmhurst': [11377, 11373],
#  'Far Rockaway': [11691],
#  'Floral Park': [11040, 11001],
#  'Flushing Meadow Park': [11375],
#  'Flushing-North': [11357, 11355, 11365, 11367, 11361],
#  'Flushing-South': [11367, 11365],
#  'Forest Hills': [11374, 11375, 11373, 11385, 11435],
#  'Fresh Meadows': [11365],
#  'Glen Oaks': [11004, 11005],
#  'Glendale': [11385, 11375, 11421, 11379],
#  'Hammels': [11693],
#  'Hillcrest': [11435, 11369, 11367],
#  'Hollis': [11432, 11423, 11435, 11427, 11369, 11429, 11433],
#  'Hollis Hills': [11427],
#  'Holliswood': [11423, 11427],
#  'Howard Beach': [11414, 11693],
#  'Jackson Heights': [11370, 11369, 11377],
#  'Jamaica': [11435, 11433],
#  'Jamaica Estates': [11432, 11423],
#  'Jamaica Hills': [11432],
#  'Kew Gardens': [11415],
#  'Laurelton': [11411, 11413, 11435, 11369],
#  'Little Neck': [11363],
#  'Long Island City': [11101, 11109],
#  'Maspeth': [11377, 11379, 11385, 11101],
#  'Middle Village': [11378, 11379, 11385, 11373],
#  'Neponsit': [11694],
#  'Oakland Gardens': [11364],
#  'Ozone Park': [11416, 11421, 11417],
#  'Queens Village': [11426, 11427, 11429, 11411, 11369],
#  'Rego Park': [11374, 11375],
#  'Richmond Hill': [11418, 11419, 11435, 11417],
#  'Ridgewood': [11385, 11379],
#  'Rockaway Park': [11694],
#  'Rosedale': [11422, 11413],
#  'So. Jamaica-Baisley Park': [11436, 11435, 11369],
#  'South Jamaica': [11435, 11433, 11417],
#  'South Ozone Park': [11420],
#  'Springfield Gardens': [11434, 11369, 11413, 11411, 11435],
#  'St. Albans': [11433, 11423, 11429, 11435, 11411, 11369],
#  'Sunnyside': [11104, 11101, 11377, 10301],
#  'Whitestone': [11357, 11355],
#  'Woodhaven': [11421],
#  'Woodside': [11377],
#  'Annadale': [10312],
#  'Arden Heights': [10312],
#  'Arrochar': [10305],
#  'Arrochar-Shore Acres': [10305],
#  'Bloomfield': [10314],
#  'Bulls Head': [10314, 10303],
#  'Castleton Corners': [10310],
#  'Clove Lakes': [10301],
#  'Concord': [10304, 10305],
#  'Concord-Fox Hills': [10304],
#  'Dongan Hills': [10304, 10305],
#  'Dongan Hills-Colony': [10304, 10301],
#  'Dongan Hills-Old Town': [10305],
#  'Eltingville': [10312],
#  'Emerson Hill': [10304, 10301],
#  'Fresh Kills': [10312],
#  'Grant City': [10304, 10305],
#  'Grasmere': [10304, 10305],
#  'Great Kills': [10306],
#  'Great Kills-Bay Terrace': [10306],
#  'Grymes Hill': [10304, 10301],
#  'Huguenot': [10312, 10309],
#  'Livingston': [10301],
#  'Manor Heights': [10314],
#  'Mariners Harbor': [10303],
#  'Midland Beach': [10305],
#  'New Brighton': [10301],
#  'New Brighton-St. George': [10301],
#  'New Dorp': [10306],
#  'New Dorp-Beach': [10306, 10309],
#  'New Dorp-Heights': [10306],
#  'New Springville': [10314],
#  'Oakwood': [10306],
#  'Oakwood-Beach': [10306],
#  'Pleasant Plains': [10309, 10307],
#  'Port Ivory': [10303],
#  'Port Richmond': [10302],
#  'Princes Bay': [10309],
#  'Richmondtown': [10306],
#  'Richmondtown-Lighths Hill': [10306],
#  'Rosebank': [10305],
#  'Rossville': [10312, 10309],
#  'Rossville-Charleston': [10309],
#  'Rossville-Port Mobil': [10309, 10303],
#  'Rossville-Richmond Valley': [10309],
#  'Silver Lake': [10301],
#  'South Beach': [10305],
#  'Stapleton': [10301],
#  'Stapleton-Clifton': [10304],
#  'Todt Hill': [10301],
#  'Tompkinsville': [10301],
#  'Tottenville': [10307],
#  'Travis': [10314],
#  'West New Brighton': [10301],
#  'Westerleigh': [10302],
#  'Willowbrook': [10314],
#  'Woodrow': [10309]}

# %%
comb=combined.copy()

# %%
def process_zip(zipy):
    for key,value in dict_zip.items():
        if zipy in value:
            return key
#process_zip = lambda zipy:dict_zip[each_record].key() if (zipy in dict_zip[each_record]) else None for each record in dict_zip
comb["loc2"]=comb["zip"].apply(process_zip)
comb["loc2"]
# Out:
# 0         Lower East Side
# 1         Lower East Side
# 2           Alphabet City
# 3         Lower East Side
# 4         Lower East Side
#               ...
# 331    Bedford Stuyvesant
# 332              Bushwick
# 333              Bushwick
# 334              Bushwick
# 335    Bedford Stuyvesant
# Name: loc2, Length: 336, dtype: object

# %%
def process_zip(zipy):
    for key,value in dict_zip.items():
        if zipy in value:
            return key
print(process_zip(10301))
# Out:
# Sunnyside

# %%
comb['zip']
# Out:
# 0      10002
# 1      10002
# 2      10009
# 3      10002
# 4      10002
#        ...
# 331    11221
# 332    11237
# 333    11237
# 334    11237
# 335    11221
# Name: zip, Length: 336, dtype: int64

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 11

# %% [markdown]
# ## Acknowledgement

# %% [markdown]
# This project is a guided project done with the guidance from Dataquest. The project was done to allow students get a better understanding of concepts of Data Cleaning.
#
# I was very keen while doing this project to ensure that it looked like an actual report. I got my answer for the same from [here](#https://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/)

# %% [markdown]
# [Index](#Index)

# %% [markdown]
# # 12

# %% [markdown]
# ## Learnings

# %% [markdown]
# - https://stackoverflow.com/questions/55014094/jupyter-notebook-not-saving-xsrf-argument-missing-from-post
# - https://seaborn.pydata.org/generated/seaborn.heatmap.html
# - https://www.pythonpool.com/matplotlib-arrow/
# - https://www.analyticsvidhya.com/blog/2021/06/style-your-pandas-dataframe-and-make-it-stunning/
# - https://www.geeksforgeeks.org/create-lollipop-charts-with-pandas-and-matplotlib/

# %% [markdown]
# [Index](#Index)
